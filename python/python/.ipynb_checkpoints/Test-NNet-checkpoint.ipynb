# %%
from EsembleNNet import EnsembleNNetSOMAC
import numpy as np

# %%
train_file = "/Users/andre.gomes/Temp/SOMAC-ML/data/14092018/somac/training_file.npy"
test_file = "/Users/andre.gomes/Temp/SOMAC-ML/data/14092018/somac/backlog_file.npy"

# %%
test_data = np.load(test_file, encoding = "latin1").item()

# %%
nnet = EnsembleNNetSOMAC()
nnet.train(train_file)

# %%
for t in range(80):
    nnet.decision(test_data[t])
    print("---")
# Out:
# Prot: 0, y = 0.03333299979567528
# y_hat_CSMA = -14.22, y_hat_TDMA = 1.39
# Evaluation: v_csma = -14.22, v_tdma = 1.39
# ---
# Prot: 1, y = 1.6448277172942956
# y_hat_CSMA = -9.34, y_hat_TDMA = 1.52
# Evaluation: v_csma = -6.4, v_tdma = 5.69
# ---
# Prot: 1, y = 3.011111338933309
# y_hat_CSMA = -5.84, y_hat_TDMA = 1.24
# Evaluation: v_csma = -2.13, v_tdma = 4.94
# ---
# Prot: 1, y = 3.8888890544573465
# y_hat_CSMA = 3.18, y_hat_TDMA = 2.57
# Evaluation: v_csma = 7.34, v_tdma = 5.96
# ---
# Prot: 1, y = 3.9245210140943527
# y_hat_CSMA = 2.16, y_hat_TDMA = 4.97
# Evaluation: v_csma = 6.64, v_tdma = 8.14
# ---
# Prot: 0, y = 12.392337332169214
# y_hat_CSMA = 5.08, y_hat_TDMA = 7.86
# Evaluation: v_csma = 9.81, v_tdma = 10.85
# ---
# Prot: 0, y = 14.13371709982554
# y_hat_CSMA = 9.7, y_hat_TDMA = 9.63
# Evaluation: v_csma = 13.73, v_tdma = 12.75
# ---
# Prot: 0, y = 12.426820558806261
# y_hat_CSMA = 8.29, y_hat_TDMA = 9.46
# Evaluation: v_csma = 11.9, v_tdma = 12.68
# ---
# Prot: 0, y = 13.833333211640516
# y_hat_CSMA = 8.18, y_hat_TDMA = 8.18
# Evaluation: v_csma = 11.49, v_tdma = 11.49
# ---
# Prot: 1, y = 9.058620888739824
# y_hat_CSMA = 6.22, y_hat_TDMA = 9.08
# Evaluation: v_csma = 9.32, v_tdma = 12.47
# ---
# Prot: 1, y = 7.5823754121859865
# y_hat_CSMA = 7.02, y_hat_TDMA = 10.0
# Evaluation: v_csma = 10.18, v_tdma = 13.16
# ---
# Prot: 1, y = 9.221073319514593
# y_hat_CSMA = 8.51, y_hat_TDMA = 12.02
# Evaluation: v_csma = 11.73, v_tdma = 15.0
# ---
# Prot: 1, y = 9.368199268976847
# y_hat_CSMA = 9.28, y_hat_TDMA = 12.26
# Evaluation: v_csma = 12.55, v_tdma = 15.09
# ---
# Prot: 0, y = 15.111110746860504
# y_hat_CSMA = 9.16, y_hat_TDMA = 11.3
# Evaluation: v_csma = 12.48, v_tdma = 14.01
# ---
# Prot: 0, y = 21.13371642678976
# y_hat_CSMA = 12.71, y_hat_TDMA = 14.32
# Evaluation: v_csma = 15.82, v_tdma = 17.06
# ---
# Prot: 0, y = 21.49540237834056
# y_hat_CSMA = 14.92, y_hat_TDMA = 15.81
# Evaluation: v_csma = 17.86, v_tdma = 18.59
# ---
# Prot: 0, y = 23.3226052771012
# y_hat_CSMA = 14.85, y_hat_TDMA = 17.82
# Evaluation: v_csma = 17.65, v_tdma = 20.62
# ---
# Prot: 1, y = 16.147893433769543
# y_hat_CSMA = 13.41, y_hat_TDMA = 18.67
# Evaluation: v_csma = 16.1, v_tdma = 21.51
# ---
# Prot: 1, y = 18.78620674709479
# y_hat_CSMA = 12.79, y_hat_TDMA = 17.65
# Evaluation: v_csma = 15.51, v_tdma = 20.36
# No. of new estimators = 10
# ---
# Prot: 1, y = 20.458621084690094
# y_hat_CSMA = 13.21, y_hat_TDMA = 18.4
# Evaluation: v_csma = 15.95, v_tdma = 21.01
# ---
# Prot: 1, y = 19.90000009536743
# y_hat_CSMA = 11.37, y_hat_TDMA = 15.9
# Evaluation: v_csma = 14.13, v_tdma = 18.42
# ---
# Prot: 0, y = 14.766666633387407
# y_hat_CSMA = 7.74, y_hat_TDMA = 12.52
# Evaluation: v_csma = 10.52, v_tdma = 14.96
# No. of new estimators = 10
# ---
# Prot: 0, y = 14.129885307202736
# y_hat_CSMA = 11.34, y_hat_TDMA = 15.87
# Evaluation: v_csma = 14.01, v_tdma = 18.33
# ---
# Prot: 0, y = 15.382375766833624
# y_hat_CSMA = 8.46, y_hat_TDMA = 12.53
# Evaluation: v_csma = 11.03, v_tdma = 15.01
# ---
# Prot: 0, y = 16.177777767181396
# y_hat_CSMA = 11.8, y_hat_TDMA = 15.45
# Evaluation: v_csma = 14.29, v_tdma = 17.94
# ---
# Prot: 1, y = 16.621839952965576
# y_hat_CSMA = 13.34, y_hat_TDMA = 17.51
# Evaluation: v_csma = 15.75, v_tdma = 20.01
# ---
# Prot: 1, y = 19.859004100163776
# y_hat_CSMA = 13.35, y_hat_TDMA = 16.97
# Evaluation: v_csma = 15.78, v_tdma = 19.4
# ---
# Prot: 1, y = 20.91839075088501
# y_hat_CSMA = 13.44, y_hat_TDMA = 16.98
# Evaluation: v_csma = 15.88, v_tdma = 19.34
# ---
# Prot: 1, y = 18.27011553446452
# y_hat_CSMA = 12.0, y_hat_TDMA = 14.76
# Evaluation: v_csma = 14.46, v_tdma = 17.05
# ---
# Prot: 0, y = 14.496168504158655
# y_hat_CSMA = 7.23, y_hat_TDMA = 10.84
# Evaluation: v_csma = 9.69, v_tdma = 13.07
# ---
# Prot: 0, y = 13.177777465432882
# y_hat_CSMA = 10.18, y_hat_TDMA = 13.05
# Evaluation: v_csma = 12.57, v_tdma = 15.3
# ---
# Prot: 0, y = 4.224904316167037
# y_hat_CSMA = 5.8, y_hat_TDMA = 8.29
# Evaluation: v_csma = 8.12, v_tdma = 10.54
# ---
# Prot: 0, y = 3.9448280135790506
# y_hat_CSMA = 5.65, y_hat_TDMA = 8.83
# Evaluation: v_csma = 7.92, v_tdma = 11.1
# ---
# Prot: 1, y = 8.85249058653911
# y_hat_CSMA = 8.62, y_hat_TDMA = 10.64
# Evaluation: v_csma = 10.83, v_tdma = 12.92
# ---
# Prot: 1, y = 11.822221954663595
# y_hat_CSMA = 10.65, y_hat_TDMA = 11.83
# Evaluation: v_csma = 12.87, v_tdma = 14.05
# ---
# Prot: 1, y = 11.85785444577535
# y_hat_CSMA = 11.38, y_hat_TDMA = 12.22
# Evaluation: v_csma = 13.61, v_tdma = 14.39
# ---
# Prot: 1, y = 11.691188017527262
# y_hat_CSMA = 8.49, y_hat_TDMA = 10.25
# Evaluation: v_csma = 10.73, v_tdma = 12.37
# No. of new estimators = 4
# ---
# Prot: 0, y = 6.1210727244615555
# y_hat_CSMA = 7.74, y_hat_TDMA = 8.81
# Evaluation: v_csma = 9.98, v_tdma = 10.89
# ---
# Prot: 0, y = 1.5888890499869983
# y_hat_CSMA = 2.51, y_hat_TDMA = 5.23
# Evaluation: v_csma = 4.71, v_tdma = 7.31
# ---
# Prot: 0, y = 0.5249039903283119
# y_hat_CSMA = 5.76, y_hat_TDMA = 5.75
# Evaluation: v_csma = 7.91, v_tdma = 7.85
# No. of new estimators = 10
# ---
# Prot: 0, y = 0.7157089834411939
# y_hat_CSMA = 6.44, y_hat_TDMA = 6.8
# Evaluation: v_csma = 8.55, v_tdma = 8.9
# ---
# Prot: 1, y = 7.780842661857605
# y_hat_CSMA = 10.4, y_hat_TDMA = 10.44
# Evaluation: v_csma = 12.46, v_tdma = 12.54
# ---
# Prot: 1, y = 10.123754978179932
# y_hat_CSMA = 6.61, y_hat_TDMA = 9.02
# Evaluation: v_csma = 8.68, v_tdma = 11.09
# ---
# Prot: 1, y = 9.766666650772095
# y_hat_CSMA = 7.4, y_hat_TDMA = 10.2
# Evaluation: v_csma = 9.47, v_tdma = 12.23
# ---
# Prot: 1, y = 10.061302481840054
# y_hat_CSMA = 7.97, y_hat_TDMA = 9.59
# Evaluation: v_csma = 10.05, v_tdma = 11.58
# ---
# Prot: 0, y = 8.055555773278078
# y_hat_CSMA = 7.87, y_hat_TDMA = 9.32
# Evaluation: v_csma = 9.95, v_tdma = 11.27
# ---
# Prot: 0, y = 6.367433716853459
# y_hat_CSMA = 8.27, y_hat_TDMA = 9.16
# Evaluation: v_csma = 10.32, v_tdma = 11.12
# ---
# Prot: 0, y = 9.022988878190517
# y_hat_CSMA = 8.11, y_hat_TDMA = 10.86
# Evaluation: v_csma = 10.12, v_tdma = 12.82
# ---
# Prot: 0, y = 16.099999323487282
# y_hat_CSMA = 11.17, y_hat_TDMA = 14.76
# Evaluation: v_csma = 13.14, v_tdma = 16.73
# ---
# Prot: 1, y = 18.440996428330738
# y_hat_CSMA = 15.29, y_hat_TDMA = 18.82
# Evaluation: v_csma = 17.23, v_tdma = 20.8
# ---
# Prot: 1, y = 19.195785760879517
# y_hat_CSMA = 14.86, y_hat_TDMA = 17.68
# Evaluation: v_csma = 16.8, v_tdma = 19.62
# ---
# Prot: 1, y = 16.216857771078747
# y_hat_CSMA = 11.82, y_hat_TDMA = 14.79
# Evaluation: v_csma = 13.77, v_tdma = 16.71
# ---
# Prot: 1, y = 18.628352284431458
# y_hat_CSMA = 14.52, y_hat_TDMA = 17.18
# Evaluation: v_csma = 16.47, v_tdma = 19.07
# ---
# Prot: 0, y = 17.744444092114765
# y_hat_CSMA = 10.51, y_hat_TDMA = 14.02
# Evaluation: v_csma = 12.47, v_tdma = 15.87
# ---
# Prot: 0, y = 14.168200060725212
# y_hat_CSMA = 10.71, y_hat_TDMA = 14.15
# Evaluation: v_csma = 12.64, v_tdma = 16.01
# ---
# Prot: 0, y = 10.24367873246471
# y_hat_CSMA = 8.65, y_hat_TDMA = 12.61
# Evaluation: v_csma = 10.55, v_tdma = 14.47
# ---
# Prot: 0, y = 9.3157087204357
# y_hat_CSMA = 11.31, y_hat_TDMA = 14.25
# Evaluation: v_csma = 13.18, v_tdma = 16.12
# ---
# Prot: 1, y = 16.0007667640845
# y_hat_CSMA = 15.73, y_hat_TDMA = 18.58
# Evaluation: v_csma = 17.57, v_tdma = 20.45
# ---
# Prot: 1, y = 14.511110762755075
# y_hat_CSMA = 14.35, y_hat_TDMA = 16.69
# Evaluation: v_csma = 16.2, v_tdma = 18.54
# No. of new estimators = 4
# ---
# Prot: 1, y = 14.999999483426413
# y_hat_CSMA = 14.08, y_hat_TDMA = 16.57
# Evaluation: v_csma = 15.93, v_tdma = 18.39
# ---
# Prot: 1, y = 16.735631903012592
# y_hat_CSMA = 12.84, y_hat_TDMA = 14.53
# Evaluation: v_csma = 14.69, v_tdma = 16.33
# ---
# Prot: 0, y = 5.339463656147321
# y_hat_CSMA = 5.18, y_hat_TDMA = 8.81
# Evaluation: v_csma = 7.03, v_tdma = 10.58
# No. of new estimators = 2
# ---
# Prot: 0, y = 0.989271675546964
# y_hat_CSMA = 3.66, y_hat_TDMA = 7.53
# Evaluation: v_csma = 5.49, v_tdma = 9.3
# ---
# Prot: 0, y = 5.623371577511231
# y_hat_CSMA = 6.94, y_hat_TDMA = 9.5
# Evaluation: v_csma = 8.74, v_tdma = 11.27
# ---
# Prot: 0, y = 11.641379412263632
# y_hat_CSMA = 12.04, y_hat_TDMA = 13.77
# Evaluation: v_csma = 13.81, v_tdma = 15.54
# ---
# Prot: 1, y = 16.695786436398823
# y_hat_CSMA = 12.38, y_hat_TDMA = 14.54
# Evaluation: v_csma = 14.14, v_tdma = 16.32
# ---
# Prot: 1, y = 17.10076693693797
# y_hat_CSMA = 13.35, y_hat_TDMA = 15.0
# Evaluation: v_csma = 15.11, v_tdma = 16.76
# ---
# Prot: 1, y = 16.990038712819416
# y_hat_CSMA = 13.59, y_hat_TDMA = 14.97
# Evaluation: v_csma = 15.35, v_tdma = 16.71
# ---
# Prot: 1, y = 16.068199316660564
# y_hat_CSMA = 13.51, y_hat_TDMA = 14.98
# Evaluation: v_csma = 15.28, v_tdma = 16.7
# ---
# Prot: 0, y = 10.909195323785147
# y_hat_CSMA = 13.09, y_hat_TDMA = 14.81
# Evaluation: v_csma = 14.86, v_tdma = 16.51
# ---
# Prot: 0, y = 11.81877359499534
# y_hat_CSMA = 12.73, y_hat_TDMA = 14.58
# Evaluation: v_csma = 14.48, v_tdma = 16.28
# ---
# Prot: 0, y = 13.899234215418497
# y_hat_CSMA = 13.82, y_hat_TDMA = 15.41
# Evaluation: v_csma = 15.54, v_tdma = 17.11
# ---
# Prot: 0, y = 19.01724125693242
# y_hat_CSMA = 12.45, y_hat_TDMA = 15.31
# Evaluation: v_csma = 14.15, v_tdma = 17.01
# ---
# Prot: 1, y = 16.034865381817024
# y_hat_CSMA = 12.68, y_hat_TDMA = 15.54
# Evaluation: v_csma = 14.36, v_tdma = 17.24
# ---
# Prot: 1, y = 16.577776906390984
# y_hat_CSMA = 14.49, y_hat_TDMA = 16.58
# Evaluation: v_csma = 16.17, v_tdma = 18.26
# ---
# Prot: 1, y = 14.771264235178629
# y_hat_CSMA = 11.82, y_hat_TDMA = 14.53
# Evaluation: v_csma = 13.51, v_tdma = 16.2
# ---
# Prot: 1, y = 16.83908059199651
# y_hat_CSMA = 13.15, y_hat_TDMA = 15.22
# Evaluation: v_csma = 14.84, v_tdma = 16.87
# No. of new estimators = 4
# ---
# Prot: 0, y = 13.155555764834086
# y_hat_CSMA = 13.64, y_hat_TDMA = 15.08
# Evaluation: v_csma = 15.33, v_tdma = 16.71
# ---
# Prot: 0, y = 11.862451955676079
# y_hat_CSMA = 9.67, y_hat_TDMA = 12.56
# Evaluation: v_csma = 11.34, v_tdma = 14.19
# ---
# Prot: 0, y = 10.722222297141949
# y_hat_CSMA = 6.76, y_hat_TDMA = 9.74
# Evaluation: v_csma = 8.41, v_tdma = 11.38
# No. of new estimators = 1
# ---
