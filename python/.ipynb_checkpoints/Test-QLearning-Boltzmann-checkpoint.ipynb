# %%
import numpy as np
import matplotlib.pyplot as plt
import logging
from QLearningBoltzmann import QLearningBoltzmann as boltz

# %%
#f_csma = "../../SOMAC-ML/data/_BKP/29092018/csma/round2/backlog_file.npy"
#f_tdma = "../../SOMAC-ML/data/_BKP/29092018/tdma/round2/backlog_file.npy"

f_csma = "../../SOMAC-ML/data/06102018/run3/3/csma/backlog_file.npy"
f_tdma = "../../SOMAC-ML/data/06102018/run3/3/tdma/backlog_file.npy"

#f_csma = "../../SOMAC-ML/data/06102018/run4/5/csma/backlog_file.npy"
#f_tdma = "../../SOMAC-ML/data/06102018/run4/5/tdma/backlog_file.npy"

d_csma = np.load(f_csma, encoding = "latin1").item()
d_tdma = np.load(f_tdma, encoding = "latin1").item()

n = np.min([len(d_csma), len(d_tdma)]) - 10

t_csma = np.array([d_csma[t]["metrics"][0, 1] for t in range(n)])
t_tdma = np.array([d_tdma[t]["metrics"][0, 1] for t in range(n)])

# %%
logging.basicConfig(filename="/Users/andre.gomes/Temp/out.log", level = logging.INFO)

prot   = 1
somac  = boltz(prot)
metric = {}
t      = 0
dt     = -1

decision = prot
backlog  = {}

# %%
def calc_reward(curr, prev):
    # Positive reward
    if curr > prev and curr <= 1.2 * prev:
        reward = 0.
        
    elif curr > 1.2 * prev and curr <= 1.4 * prev:
        reward = 1.
        
    elif curr > 1.4 * prev and curr <= 1.6 * prev:
        reward = 2.
        
    elif curr > 1.6 * prev and curr <= 1.8 * prev:
        reward = 3.
        
    elif curr > 1.8 * prev and curr <= 2.0 * prev:
        reward = 4.
        
    elif curr > 2.0 * prev:
        reward = 5.

    # Negative reward
    elif prev > curr and prev <= 1.2 * curr:
        reward = 0.

    elif prev > 1.2 * curr and prev <= 1.4 * curr:
        reward = -1.
        
    elif prev > 1.4 * curr and prev <= 1.6 * curr:
        reward = -2.
        
    elif prev > 1.6 * curr and prev <= 1.8 * curr:
        reward = -3.
        
    elif prev > 1.8 * curr and prev <= 2.0 * curr:
        reward = -4.
        
    elif prev > 2.0 * curr:
        reward = -5.

    else:
        reward = 0.

    return reward

while t < n:
    metric[t] = t_csma[t] if prot == 0 else t_tdma[t]
    print("Metrics = {}".format(metric[t]))
    print("t = {}, dt = {}".format(t, dt))
    
    backlog[t] = prot
    
    if dt > 1:
        if dt == 2:
            reward = calc_reward(metric[t], metric[t-2])
        elif dt == 3:
            reward = calc_reward(metric[t], metric[t-3])
        else:
            reward = calc_reward(metric[t], metric[t-1]) * 0.01
            #reward = reward if reward == 0 else reward ** -dt
            
        somac.update_qtable(reward, np.sqrt(dt))
        
        if dt == 2 and reward > 0:
            decision = somac.decision(prot, keep = True)
        elif dt == 2 and reward < 0.:
            decision = somac.decision(prot, force_switch = True)
        else:
            decision = somac.decision(prot, keep = False)
        
        if decision != prot:
            dt = 0
    else:
        print("MAC prot was switched recently. No switch now")
    
    
    t = t + 1
    dt = dt + 1
    
    print("Protocol: {}".format(
        "CSMA" if prot == 0 else "TDMA"
    ))
    
    prot = decision
    
    print("Decision: {}".format(
        "CSMA" if prot == 0 else "TDMA"
    ))
    
    print("\n=============================\n")
# Out:
# Metrics = 1.6833329759538174
# t = 0, dt = -1
# MAC prot was switched recently. No switch now
# Protocol: TDMA
# Decision: TDMA
#
# =============================
#
# Metrics = 3.5499995313584805
# t = 1, dt = 0
# MAC prot was switched recently. No switch now
# Protocol: TDMA
# Decision: TDMA
#
# =============================
#
# Metrics = 3.0333333890885115
# t = 2, dt = 1
# MAC prot was switched recently. No switch now
# Protocol: TDMA
# Decision: TDMA
#
# =============================
#
# Metrics = 3.3333334922790527
# t = 3, dt = 2
# Protocol: TDMA
# Decision: TDMA
#
# =============================
#
# Metrics = 3.407471537590027
# t = 4, dt = 3
# Protocol: TDMA
# Decision: CSMA
#
# =============================
#
# Metrics = 4.266666650772095
# t = 5, dt = 1
# MAC prot was switched recently. No switch now
# Protocol: CSMA
# Decision: CSMA
#
# =============================
#
# Metrics = 7.066666513681412
# t = 6, dt = 2
# Protocol: CSMA
# Decision: CSMA
#
# =============================
#
# Metrics = 10.116667032241821
# t = 7, dt = 3
# Protocol: CSMA
# Decision: CSMA
#
# =============================
#
# Metrics = 9.749999849125743
# t = 8, dt = 4
# Protocol: CSMA
# Decision: CSMA
#
# =============================
#
# Metrics = 13.266666650772095
# t = 9, dt = 5
# Protocol: CSMA
# Decision: CSMA
#
# =============================
#
# Metrics = 11.433333396911621
# t = 10, dt = 6
# Protocol: CSMA
# Decision: CSMA
#
# =============================
#
# Metrics = 12.548276424407959
# t = 11, dt = 7
# Protocol: CSMA
# Decision: CSMA
#
# =============================
#
# Metrics = 15.016665995121002
# t = 12, dt = 8
# Protocol: CSMA
# Decision: CSMA
#
# =============================
#
# Metrics = 16.72471249103546
# t = 13, dt = 9
# Protocol: CSMA
# Decision: CSMA
#
# =============================
#
# Metrics = 15.483333587646484
# t = 14, dt = 10
# Protocol: CSMA
# Decision: TDMA
#
# =============================
#
# Metrics = 10.291379451751709
# t = 15, dt = 1
# MAC prot was switched recently. No switch now
# Protocol: TDMA
# Decision: TDMA
#
# =============================
#
# Metrics = 10.233333110809326
# t = 16, dt = 2
# Protocol: TDMA
# Decision: CSMA
#
# =============================
#
# Metrics = 15.266666412353516
# t = 17, dt = 1
# MAC prot was switched recently. No switch now
# Protocol: CSMA
# Decision: CSMA
#
# =============================
#
# Metrics = 19.449999570846558
# t = 18, dt = 2
# Protocol: CSMA
# Decision: CSMA
#
# =============================
#
# Metrics = 23.466665983200073
# t = 19, dt = 3
# Protocol: CSMA
# Decision: CSMA
#
# =============================
#
# Metrics = 23.68333351612091
# t = 20, dt = 4
# Protocol: CSMA
# Decision: CSMA
#
# =============================
#
# Metrics = 19.516666740179062
# t = 21, dt = 5
# Protocol: CSMA
# Decision: CSMA
#
# =============================
#
# Metrics = 23.33735680580139
# t = 22, dt = 6
# Protocol: CSMA
# Decision: CSMA
#
# =============================
#
# Metrics = 23.3103449344635
# t = 23, dt = 7
# Protocol: CSMA
# Decision: CSMA
#
# =============================
#
# Metrics = 22.77988496236503
# t = 24, dt = 8
# Protocol: CSMA
# Decision: CSMA
#
# =============================
#
# Metrics = 23.67873600870371
# t = 25, dt = 9
# Protocol: CSMA
# Decision: CSMA
#
# =============================
#
# Metrics = 21.397126389667392
# t = 26, dt = 10
# Protocol: CSMA
# Decision: CSMA
#
# =============================
#
# Metrics = 20.627586990594864
# t = 27, dt = 11
# Protocol: CSMA
# Decision: TDMA
#
# =============================
#
# Metrics = 13.69999953918159
# t = 28, dt = 1
# MAC prot was switched recently. No switch now
# Protocol: TDMA
# Decision: TDMA
#
# =============================
#
# Metrics = 13.832758903503418
# t = 29, dt = 2
# Protocol: TDMA
# Decision: CSMA
#
# =============================
#
# Metrics = 22.283333331346512
# t = 30, dt = 1
# MAC prot was switched recently. No switch now
# Protocol: CSMA
# Decision: CSMA
#
# =============================
#
# Metrics = 23.24712646007538
# t = 31, dt = 2
# Protocol: CSMA
# Decision: CSMA
#
# =============================
#
# Metrics = 21.26666685938835
# t = 32, dt = 3
# Protocol: CSMA
# Decision: CSMA
#
# =============================
#
# Metrics = 23.035057701170444
# t = 33, dt = 4
# Protocol: CSMA
# Decision: CSMA
#
# =============================
#
# Metrics = 22.86149402335286
# t = 34, dt = 5
# Protocol: CSMA
# Decision: CSMA
#
# =============================
#
# Metrics = 22.100000547245145
# t = 35, dt = 6
# Protocol: CSMA
# Decision: CSMA
#
# =============================
#
# Metrics = 23.438505932688713
# t = 36, dt = 7
# Protocol: CSMA
# Decision: CSMA
#
# =============================
#
# Metrics = 21.466666791588068
# t = 37, dt = 8
# Protocol: CSMA
# Decision: CSMA
#
# =============================
#
# Metrics = 22.40804574266076
# t = 38, dt = 9
# Protocol: CSMA
# Decision: CSMA
#
# =============================
#
# Metrics = 23.649999456480145
# t = 39, dt = 10
# Protocol: CSMA
# Decision: TDMA
#
# =============================
#
# Metrics = 19.23333402350545
# t = 40, dt = 1
# MAC prot was switched recently. No switch now
# Protocol: TDMA
# Decision: TDMA
#
# =============================
#
# Metrics = 19.254023153334856
# t = 41, dt = 2
# Protocol: TDMA
# Decision: CSMA
#
# =============================
#
# Metrics = 22.439080599695444
# t = 42, dt = 1
# MAC prot was switched recently. No switch now
# Protocol: CSMA
# Decision: CSMA
#
# =============================
#
# Metrics = 25.91953995451331
# t = 43, dt = 2
# Protocol: CSMA
# Decision: CSMA
#
# =============================
#
# Metrics = 25.693678695708513
# t = 44, dt = 3
# Protocol: CSMA
# Decision: CSMA
#
# =============================
#
# Metrics = 26.5086210668087
# t = 45, dt = 4
# Protocol: CSMA
# Decision: CSMA
#
# =============================
#
# Metrics = 25.78333354368806
# t = 46, dt = 5
# Protocol: CSMA
# Decision: CSMA
#
# =============================
#
# Metrics = 22.293103452771902
# t = 47, dt = 6
# Protocol: CSMA
# Decision: CSMA
#
# =============================
#
# Metrics = 24.684483394026756
# t = 48, dt = 7
# Protocol: CSMA
# Decision: CSMA
#
# =============================
#
# Metrics = 25.166666861623526
# t = 49, dt = 8
# Protocol: CSMA
# Decision: CSMA
#
# =============================
#
# Metrics = 24.498851330950856
# t = 50, dt = 9
# Protocol: CSMA
# Decision: TDMA
#
# =============================
#
# Metrics = 25.564941883087158
# t = 51, dt = 1
# MAC prot was switched recently. No switch now
# Protocol: TDMA
# Decision: TDMA
#
# =============================
#
# Metrics = 25.766666619107127
# t = 52, dt = 2
# Protocol: TDMA
# Decision: CSMA
#
# =============================
#
# Metrics = 26.631609700620174
# t = 53, dt = 1
# MAC prot was switched recently. No switch now
# Protocol: CSMA
# Decision: CSMA
#
# =============================
#
# Metrics = 23.05287403613329
# t = 54, dt = 2
# Protocol: CSMA
# Decision: TDMA
#
# =============================
#
# Metrics = 18.3333319760859
# t = 55, dt = 1
# MAC prot was switched recently. No switch now
# Protocol: TDMA
# Decision: TDMA
#
# =============================
#
# Metrics = 2.850000023841858
# t = 56, dt = 2
# Protocol: TDMA
# Decision: CSMA
#
# =============================
#
# Metrics = 0.23333300463855267
# t = 57, dt = 1
# MAC prot was switched recently. No switch now
# Protocol: CSMA
# Decision: CSMA
#
# =============================
#
# Metrics = 0.35344800911843777
# t = 58, dt = 2
# Protocol: CSMA
# Decision: TDMA
#
# =============================
#
# Metrics = 2.633333444595337
# t = 59, dt = 1
# MAC prot was switched recently. No switch now
# Protocol: TDMA
# Decision: TDMA
#
# =============================
#
# Metrics = 3.116666553542018
# t = 60, dt = 2
# Protocol: TDMA
# Decision: TDMA
#
# =============================
#
# Metrics = 6.065517513081431
# t = 61, dt = 3
# Protocol: TDMA
# Decision: TDMA
#
# =============================
#
# Metrics = 6.121264426037669
# t = 62, dt = 4
# Protocol: TDMA
# Decision: TDMA
#
# =============================
#
# Metrics = 5.6333335638046265
# t = 63, dt = 5
# Protocol: TDMA
# Decision: TDMA
#
# =============================
#
# Metrics = 6.0833330154418945
# t = 64, dt = 6
# Protocol: TDMA
# Decision: TDMA
#
# =============================
#
# Metrics = 5.950000016018748
# t = 65, dt = 7
# Protocol: TDMA
# Decision: CSMA
#
# =============================
#
# Metrics = 0.08333299867808819
# t = 66, dt = 1
# MAC prot was switched recently. No switch now
# Protocol: CSMA
# Decision: CSMA
#
# =============================
#
# Metrics = 0.3333334978669882
# t = 67, dt = 2
# Protocol: CSMA
# Decision: TDMA
#
# =============================
#
# Metrics = 8.952298521995544
# t = 68, dt = 1
# MAC prot was switched recently. No switch now
# Protocol: TDMA
# Decision: TDMA
#
# =============================
#
# Metrics = 8.998276114463806
# t = 69, dt = 2
# Protocol: TDMA
# Decision: TDMA
#
# =============================
#
# Metrics = 8.785057425498962
# t = 70, dt = 3
# Protocol: TDMA
# Decision: TDMA
#
# =============================
#
# Metrics = 8.882758021354675
# t = 71, dt = 4
# Protocol: TDMA
# Decision: TDMA
#
# =============================
#
# Metrics = 9.116666553542018
# t = 72, dt = 5
# Protocol: TDMA
# Decision: TDMA
#
# =============================
#
# Metrics = 12.366666913032532
# t = 73, dt = 6
# Protocol: TDMA
# Decision: TDMA
#
# =============================
#
# Metrics = 12.5666663646698
# t = 74, dt = 7
# Protocol: TDMA
# Decision: TDMA
#
# =============================
#
# Metrics = 12.816666452214122
# t = 75, dt = 8
# Protocol: TDMA
# Decision: TDMA
#
# =============================
#
# Metrics = 12.48333352431655
# t = 76, dt = 9
# Protocol: TDMA
# Decision: TDMA
#
# =============================
#
# Metrics = 12.400000095367432
# t = 77, dt = 10
# Protocol: TDMA
# Decision: TDMA
#
# =============================
#
# Metrics = 12.883332546800375
# t = 78, dt = 11
# Protocol: TDMA
# Decision: TDMA
#
# =============================
#
# Metrics = 16.15057441405952
# t = 79, dt = 12
# Protocol: TDMA
# Decision: TDMA
#
# =============================
#
# Metrics = 16.077585546299815
# t = 80, dt = 13
# Protocol: TDMA
# Decision: TDMA
#
# =============================
#
# Metrics = 15.674713341519237
# t = 81, dt = 14
# Protocol: TDMA
# Decision: TDMA
#
# =============================
#
# Metrics = 15.744252443313599
# t = 82, dt = 15
# Protocol: TDMA
# Decision: TDMA
#
# =============================
#
# Metrics = 16.311493126675487
# t = 83, dt = 16
# Protocol: TDMA
# Decision: TDMA
#
# =============================
#
# Metrics = 16.617815194651484
# t = 84, dt = 17
# Protocol: TDMA
# Decision: TDMA
#
# =============================
#
# Metrics = 19.282183941453695
# t = 85, dt = 18
# Protocol: TDMA
# Decision: TDMA
#
# =============================
#
# Metrics = 19.210345029830933
# t = 86, dt = 19
# Protocol: TDMA
# Decision: TDMA
#
# =============================
#
# Metrics = 19.22873540595174
# t = 87, dt = 20
# Protocol: TDMA
# Decision: TDMA
#
# =============================
#
# Metrics = 19.433333095163107
# t = 88, dt = 21
# Protocol: TDMA
# Decision: CSMA
#
# =============================
#
# Metrics = 9.283908208832145
# t = 89, dt = 1
# MAC prot was switched recently. No switch now
# Protocol: CSMA
# Decision: CSMA
#
# =============================
#
# Metrics = 10.081609513610601
# t = 90, dt = 2
# Protocol: CSMA
# Decision: TDMA
#
# =============================
#
# Metrics = 22.050000127404928
# t = 91, dt = 1
# MAC prot was switched recently. No switch now
# Protocol: TDMA
# Decision: TDMA
#
# =============================
#
# Metrics = 22.61206829547882
# t = 92, dt = 2
# Protocol: TDMA
# Decision: TDMA
#
# =============================
#
# Metrics = 22.581033524125814
# t = 93, dt = 3
# Protocol: TDMA
# Decision: TDMA
#
# =============================
#
# Metrics = 21.943677600473166
# t = 94, dt = 4
# Protocol: TDMA
# Decision: TDMA
#
# =============================
#
# Metrics = 22.86034449748695
# t = 95, dt = 5
# Protocol: TDMA
# Decision: TDMA
#
# =============================
#
# Metrics = 22.83793079853058
# t = 96, dt = 6
# Protocol: TDMA
# Decision: TDMA
#
# =============================
#
# Metrics = 25.524139046669006
# t = 97, dt = 7
# Protocol: TDMA
# Decision: TDMA
#
# =============================
#
# Metrics = 25.449999451637268
# t = 98, dt = 8
# Protocol: TDMA
# Decision: TDMA
#
# =============================
#
# Metrics = 25.14597761631012
# t = 99, dt = 9
# Protocol: TDMA
# Decision: TDMA
#
# =============================
#
# Metrics = 25.549999475479126
# t = 100, dt = 10
# Protocol: TDMA
# Decision: TDMA
#
# =============================
#
# Metrics = 25.611494183540344
# t = 101, dt = 11
# Protocol: TDMA
# Decision: TDMA
#
# =============================
#
# Metrics = 25.297701597213745
# t = 102, dt = 12
# Protocol: TDMA
# Decision: TDMA
#
# =============================
#
# Metrics = 25.700573801994324
# t = 103, dt = 13
# Protocol: TDMA
# Decision: TDMA
#
# =============================
#
# Metrics = 26.166666444391012
# t = 104, dt = 14
# Protocol: TDMA
# Decision: TDMA
#
# =============================
#
# Metrics = 25.450000047683716
# t = 105, dt = 15
# Protocol: TDMA
# Decision: TDMA
#
# =============================

# %%
n_csma  = 0
n_tdma  = 0
n_somac = 0
n_changes = 0

for t in range(n):
    if t_csma[t] >= .9 * t_tdma[t]:
        n_csma = n_csma + 1
        
        if backlog[t] == 0:
            n_somac = n_somac + 1

    if t_tdma[t] >= .9 * t_csma[t]:
        n_tdma = n_tdma + 1
        
        if backlog[t] == 1:
            n_somac = n_somac + 1
        
for t in range(1, n, 1):
    if backlog[t-1] != backlog[t]:
        n_changes = n_changes + 1
        
print("CSMA count = {}%, TDMA count = {}%".format(
    round(n_csma * 1. / n, 2),
    round(n_tdma * 1. / n, 2)
))
print("Taxa de acerto = {}%".format(round(n_somac * 1. / n, 2)))
print("No. de trocas = {}".format(n_changes))
print("n = {}".format(n))

print("Desempenho médio:\nCSMA = {}, TDMA = {}, SOMAC = {}".format(
    round(np.mean(t_csma), 2),
    round(np.mean(t_tdma), 2),
    round(np.mean([metric[t] for t in range(n)]), 2)
))

norm = np.max([
    round(np.mean(t_csma), 2),
    round(np.mean(t_tdma), 2),
    round(np.mean([metric[t] for t in range(n)]), 2)
])

print("Desempenho médio (%):\nCSMA = {}, TDMA = {}, SOMAC = {}".format(
    round(np.mean(t_csma) / norm, 2),
    round(np.mean(t_tdma) / norm, 2),
    round(np.mean([metric[t] for t in range(n)]) / norm, 2)
))
# Out:
# CSMA count = 0.56%, TDMA count = 0.59%
# Taxa de acerto = 0.83%
# No. de trocas = 16
# n = 106
# Desempenho médio:
# CSMA = 13.81, TDMA = 14.92, SOMAC = 16.41
# Desempenho médio (%):
# CSMA = 0.84, TDMA = 0.91, SOMAC = 1.0

# %%
t = np.arange(n)

plt.plot(
    t, t_csma,
    t, t_tdma,
    t, [metric[i] for i in range(n)]
)
# Out:
# [<matplotlib.lines.Line2D at 0x12927e208>,
#  <matplotlib.lines.Line2D at 0x12927e358>,
#  <matplotlib.lines.Line2D at 0x12927e898>]

# %%
plt.plot(t, [backlog[i] for i in range(n)])
