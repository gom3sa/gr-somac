# %%
from EsembleNNet import EnsembleNNetSOMAC
import numpy as np

# %%
train_file = "/Users/andre.gomes/Temp/SOMAC-ML/data/14092018/somac/training_file.npy"
test_file = "/Users/andre.gomes/Temp/SOMAC-ML/data/14092018/somac/backlog_file.npy"

# %%
test_data = np.load(test_file, encoding = "latin1").item()

# %%
nnet = EnsembleNNetSOMAC()
nnet.train(train_file)

# %%
for t in range(80):
    nnet.decision(test_data[t])
    print("---")
# Out:
# Prot: 0, y = 0.16666649281978607
# y_hat_CSMA = -15.54, y_hat_TDMA = -0.19
# Evaluation: v_csma = -15.54, v_tdma = -0.19
# ---
# Prot: 0, y = 0.2758620008826256
# y_hat_CSMA = -15.09, y_hat_TDMA = 0.26
# Evaluation: v_csma = -12.15, v_tdma = 4.42
# ---
# Prot: 0, y = 0.1189655028283596
# y_hat_CSMA = -1.08, y_hat_TDMA = 0.01
# Evaluation: v_csma = 1.95, v_tdma = 5.25
# ---
# Prot: 0, y = 0.05000000074505806
# y_hat_CSMA = 0.52, y_hat_TDMA = -0.83
# Evaluation: v_csma = 3.47, v_tdma = 5.06
# ---
# Prot: 0, y = 0.03333349898457527
# y_hat_CSMA = 16.34, y_hat_TDMA = 2.14
# Evaluation: v_csma = 19.18, v_tdma = 8.48
# ---
# Prot: 0, y = 0.1333335041999817
# y_hat_CSMA = 16.76, y_hat_TDMA = 2.14
# Evaluation: v_csma = 19.49, v_tdma = 8.84
# ---
# Prot: 0, y = 0.20000000298023224
# y_hat_CSMA = 16.98, y_hat_TDMA = 2.16
# Evaluation: v_csma = 19.61, v_tdma = 9.13
# ---
# Prot: 0, y = 0.4166665133088827
# y_hat_CSMA = 21.37, y_hat_TDMA = 4.08
# Evaluation: v_csma = 23.92, v_tdma = 11.29
# ---
# Prot: 0, y = 0.1333335041999817
# y_hat_CSMA = 18.79, y_hat_TDMA = 3.6
# Evaluation: v_csma = 21.26, v_tdma = 11.01
# ---
# Prot: 0, y = 0.4735630042850971
# y_hat_CSMA = 21.88, y_hat_TDMA = 5.43
# Evaluation: v_csma = 24.28, v_tdma = 13.01
# No. of new estimators = 10
# ---
# Prot: 0, y = 0.30000000447034836
# y_hat_CSMA = 17.63, y_hat_TDMA = 3.83
# Evaluation: v_csma = 19.96, v_tdma = 11.57
# ---
# Prot: 1, y = 2.133333493024111
# y_hat_CSMA = 17.25, y_hat_TDMA = 3.76
# Evaluation: v_csma = 19.53, v_tdma = 11.64
# ---
# Prot: 1, y = 6.916666865348816
# y_hat_CSMA = 21.99, y_hat_TDMA = 6.05
# Evaluation: v_csma = 24.3, v_tdma = 11.71
# ---
# Prot: 0, y = 8.033333539962769
# y_hat_CSMA = 24.07, y_hat_TDMA = 8.83
# Evaluation: v_csma = 26.41, v_tdma = 13.52
# ---
# Prot: 0, y = 0.3166665006428957
# y_hat_CSMA = 16.48, y_hat_TDMA = 3.92
# Evaluation: v_csma = 18.76, v_tdma = 8.68
# ---
# Prot: 1, y = 4.100000007078052
# y_hat_CSMA = 24.08, y_hat_TDMA = 9.45
# Evaluation: v_csma = 26.31, v_tdma = 14.25
# ---
# Prot: 0, y = 7.051723822951317
# y_hat_CSMA = 24.18, y_hat_TDMA = 9.44
# Evaluation: v_csma = 26.43, v_tdma = 13.65
# ---
# Prot: 0, y = 0.733333021402359
# y_hat_CSMA = 23.73, y_hat_TDMA = 9.45
# Evaluation: v_csma = 25.92, v_tdma = 13.7
# ---
# Prot: 0, y = 1.8166670091450214
# y_hat_CSMA = 20.29, y_hat_TDMA = 5.84
# Evaluation: v_csma = 22.43, v_tdma = 10.13
# ---
# Prot: 0, y = 2.916666530072689
# y_hat_CSMA = 26.48, y_hat_TDMA = 12.78
# Evaluation: v_csma = 28.57, v_tdma = 17.11
# ---
# Prot: 0, y = 1.4999990034848452
# y_hat_CSMA = 27.11, y_hat_TDMA = 13.06
# Evaluation: v_csma = 29.17, v_tdma = 17.43
# ---
# Prot: 0, y = 1.8333329912275076
# y_hat_CSMA = 23.98, y_hat_TDMA = 11.03
# Evaluation: v_csma = 26.0, v_tdma = 15.42
# ---
# Prot: 0, y = 2.883333060890436
# y_hat_CSMA = 23.14, y_hat_TDMA = 8.83
# Evaluation: v_csma = 25.12, v_tdma = 13.26
# No. of new estimators = 10
# ---
# Prot: 0, y = 0.9028739891946316
# y_hat_CSMA = 20.69, y_hat_TDMA = 11.22
# Evaluation: v_csma = 22.63, v_tdma = 15.68
# ---
# Prot: 0, y = 4.910919472575188
# y_hat_CSMA = 19.54, y_hat_TDMA = 9.21
# Evaluation: v_csma = 21.46, v_tdma = 13.7
# ---
# Prot: 0, y = 10.743678409606218
# y_hat_CSMA = 26.32, y_hat_TDMA = 14.59
# Evaluation: v_csma = 28.2, v_tdma = 19.1
# ---
# Prot: 0, y = 9.882758498191833
# y_hat_CSMA = 23.83, y_hat_TDMA = 11.52
# Evaluation: v_csma = 25.68, v_tdma = 16.06
# ---
# Prot: 0, y = 9.949999988079071
# y_hat_CSMA = 21.28, y_hat_TDMA = 12.72
# Evaluation: v_csma = 23.11, v_tdma = 17.29
# ---
# Prot: 0, y = 8.91781634092331
# y_hat_CSMA = 21.09, y_hat_TDMA = 12.67
# Evaluation: v_csma = 22.89, v_tdma = 17.26
# ---
# Prot: 0, y = 8.383908420801163
# y_hat_CSMA = 21.46, y_hat_TDMA = 9.9
# Evaluation: v_csma = 23.23, v_tdma = 14.51
# ---
# Prot: 0, y = 11.750000514090061
# y_hat_CSMA = 24.28, y_hat_TDMA = 13.01
# Evaluation: v_csma = 26.03, v_tdma = 17.64
# ---
# Prot: 0, y = 14.724713265895844
# y_hat_CSMA = 27.36, y_hat_TDMA = 14.9
# Evaluation: v_csma = 29.09, v_tdma = 19.56
# ---
# Prot: 0, y = 13.083333998918533
# y_hat_CSMA = 26.67, y_hat_TDMA = 14.54
# Evaluation: v_csma = 28.37, v_tdma = 19.21
# No. of new estimators = 10
# ---
# Prot: 0, y = 17.635632053017616
# y_hat_CSMA = 23.29, y_hat_TDMA = 14.6
# Evaluation: v_csma = 24.98, v_tdma = 19.29
# ---
# Prot: 0, y = 15.716667026281357
# y_hat_CSMA = 24.97, y_hat_TDMA = 16.89
# Evaluation: v_csma = 26.63, v_tdma = 21.61
# ---
# Prot: 0, y = 17.36666637659073
# y_hat_CSMA = 19.31, y_hat_TDMA = 10.79
# Evaluation: v_csma = 20.96, v_tdma = 15.52
# ---
# Prot: 1, y = 16.383907187730074
# y_hat_CSMA = 26.53, y_hat_TDMA = 17.54
# Evaluation: v_csma = 28.15, v_tdma = 22.3
# ---
# Prot: 0, y = 16.57356345653534
# y_hat_CSMA = 28.64, y_hat_TDMA = 23.19
# Evaluation: v_csma = 30.27, v_tdma = 27.46
# ---
# Prot: 0, y = 24.733333542943
# y_hat_CSMA = 26.1, y_hat_TDMA = 21.28
# Evaluation: v_csma = 27.72, v_tdma = 25.56
# ---
# Prot: 0, y = 24.066666461527348
# y_hat_CSMA = 25.87, y_hat_TDMA = 20.94
# Evaluation: v_csma = 27.47, v_tdma = 25.24
# ---
# Prot: 0, y = 18.854023329913616
# y_hat_CSMA = 28.3, y_hat_TDMA = 23.06
# Evaluation: v_csma = 29.88, v_tdma = 27.37
# ---
# Prot: 0, y = 24.756321247667074
# y_hat_CSMA = 25.07, y_hat_TDMA = 19.56
# Evaluation: v_csma = 26.64, v_tdma = 23.89
# ---
# Prot: 0, y = 26.100000955164433
# y_hat_CSMA = 27.24, y_hat_TDMA = 21.17
# Evaluation: v_csma = 28.79, v_tdma = 25.51
# ---
# Prot: 0, y = 29.66494370996952
# y_hat_CSMA = 26.69, y_hat_TDMA = 19.31
# Evaluation: v_csma = 28.23, v_tdma = 23.66
# No. of new estimators = 10
# ---
# Prot: 0, y = 29.97586240619421
# y_hat_CSMA = 25.78, y_hat_TDMA = 20.97
# Evaluation: v_csma = 27.31, v_tdma = 25.33
# ---
# Prot: 0, y = 29.785631518810987
# y_hat_CSMA = 27.26, y_hat_TDMA = 22.76
# Evaluation: v_csma = 28.77, v_tdma = 27.14
# ---
# Prot: 0, y = 31.40287342481315
# y_hat_CSMA = 24.63, y_hat_TDMA = 18.58
# Evaluation: v_csma = 26.12, v_tdma = 22.97
# ---
# Prot: 0, y = 33.03735616616905
# y_hat_CSMA = 26.2, y_hat_TDMA = 20.62
# Evaluation: v_csma = 27.69, v_tdma = 25.01
# ---
# Prot: 0, y = 25.86896612495184
# y_hat_CSMA = 26.67, y_hat_TDMA = 21.25
# Evaluation: v_csma = 28.14, v_tdma = 25.66
# ---
# Prot: 0, y = 15.201149892061949
# y_hat_CSMA = 14.02, y_hat_TDMA = 11.92
# Evaluation: v_csma = 15.48, v_tdma = 16.35
# ---
# Prot: 1, y = 10.529310837388039
# y_hat_CSMA = 10.46, y_hat_TDMA = 9.2
# Evaluation: v_csma = 11.91, v_tdma = 13.63
# ---
# Prot: 1, y = 11.864367604255676
# y_hat_CSMA = 9.87, y_hat_TDMA = 6.66
# Evaluation: v_csma = 11.32, v_tdma = 10.72
# ---
# Prot: 1, y = 5.138505503535271
# y_hat_CSMA = 8.79, y_hat_TDMA = 2.42
# Evaluation: v_csma = 10.25, v_tdma = 6.19
# ---
# Prot: 1, y = 3.716666579246521
# y_hat_CSMA = 8.77, y_hat_TDMA = 2.13
# Evaluation: v_csma = 10.22, v_tdma = 5.66
# ---
# Prot: 1, y = 3.649999976158142
# y_hat_CSMA = 8.76, y_hat_TDMA = 2.19
# Evaluation: v_csma = 10.22, v_tdma = 5.53
# ---
# Prot: 1, y = 6.71666693687439
# y_hat_CSMA = 11.36, y_hat_TDMA = 3.55
# Evaluation: v_csma = 12.82, v_tdma = 6.72
# No. of new estimators = 10
# ---
# Prot: 0, y = 10.90114951133728
# y_hat_CSMA = 11.97, y_hat_TDMA = 5.31
# Evaluation: v_csma = 13.44, v_tdma = 8.34
# ---
# Prot: 0, y = 17.21666669845581
# y_hat_CSMA = 11.78, y_hat_TDMA = 4.23
# Evaluation: v_csma = 13.23, v_tdma = 7.27
# ---
# Prot: 0, y = 19.53333330154419
# y_hat_CSMA = 10.9, y_hat_TDMA = 2.93
# Evaluation: v_csma = 12.34, v_tdma = 5.98
# ---
# Prot: 0, y = 19.409769535064697
# y_hat_CSMA = 11.18, y_hat_TDMA = 1.39
# Evaluation: v_csma = 12.61, v_tdma = 4.44
# No. of new estimators = 10
# ---
# Prot: 0, y = 16.149999618530273
# y_hat_CSMA = 12.92, y_hat_TDMA = 1.84
# Evaluation: v_csma = 14.34, v_tdma = 4.9
# ---
# Prot: 0, y = 24.96666646003723
# y_hat_CSMA = 15.41, y_hat_TDMA = 1.89
# Evaluation: v_csma = 16.82, v_tdma = 4.96
# ---
# Prot: 0, y = 25.166666507720947
# y_hat_CSMA = 15.57, y_hat_TDMA = 1.87
# Evaluation: v_csma = 16.97, v_tdma = 4.94
# ---
# Prot: 0, y = 25.68333339691162
# y_hat_CSMA = 15.46, y_hat_TDMA = 2.07
# Evaluation: v_csma = 16.85, v_tdma = 5.14
# ---
# Prot: 0, y = 25.31666612625122
# y_hat_CSMA = 16.55, y_hat_TDMA = 2.03
# Evaluation: v_csma = 17.93, v_tdma = 5.11
# ---
# Prot: 0, y = 25.733333587646484
# y_hat_CSMA = 15.64, y_hat_TDMA = 1.97
# Evaluation: v_csma = 17.01, v_tdma = 5.05
# ---
# Prot: 0, y = 25.121264457702637
# y_hat_CSMA = 15.24, y_hat_TDMA = 1.87
# Evaluation: v_csma = 16.59, v_tdma = 4.96
# ---
# Prot: 0, y = 30.089654207229614
# y_hat_CSMA = 19.84, y_hat_TDMA = 3.28
# Evaluation: v_csma = 21.19, v_tdma = 6.38
# ---
# Prot: 0, y = 30.40574812889099
# y_hat_CSMA = 18.89, y_hat_TDMA = 5.41
# Evaluation: v_csma = 20.23, v_tdma = 8.52
# ---
# Prot: 0, y = 29.716665983200073
# y_hat_CSMA = 18.66, y_hat_TDMA = 6.31
# Evaluation: v_csma = 19.99, v_tdma = 9.42
# No. of new estimators = 10
# ---
# Prot: 0, y = 30.40000033378601
# y_hat_CSMA = 20.73, y_hat_TDMA = 6.11
# Evaluation: v_csma = 22.05, v_tdma = 9.22
# ---
# Prot: 0, y = 31.43333339691162
# y_hat_CSMA = 20.53, y_hat_TDMA = 6.16
# Evaluation: v_csma = 21.85, v_tdma = 9.27
# ---
# Prot: 0, y = 31.016666412353516
# y_hat_CSMA = 20.54, y_hat_TDMA = 6.12
# Evaluation: v_csma = 21.84, v_tdma = 9.24
# ---
# Prot: 0, y = 33.120115637779236
# y_hat_CSMA = 23.51, y_hat_TDMA = 8.63
# Evaluation: v_csma = 24.8, v_tdma = 11.76
# ---
# Prot: 0, y = 34.325862765312195
# y_hat_CSMA = 24.23, y_hat_TDMA = 10.05
# Evaluation: v_csma = 25.52, v_tdma = 13.18
# ---
# Prot: 0, y = 31.27988526970148
# y_hat_CSMA = 25.48, y_hat_TDMA = 10.56
# Evaluation: v_csma = 26.76, v_tdma = 13.69
# ---
# Prot: 0, y = 31.33333334326744
# y_hat_CSMA = 23.55, y_hat_TDMA = 9.79
# Evaluation: v_csma = 24.82, v_tdma = 12.94
# ---
# Prot: 0, y = 31.488506078720093
# y_hat_CSMA = 23.93, y_hat_TDMA = 9.81
# Evaluation: v_csma = 25.19, v_tdma = 12.96
# ---
# Prot: 0, y = 30.033333629369736
# y_hat_CSMA = 23.84, y_hat_TDMA = 9.77
# Evaluation: v_csma = 25.1, v_tdma = 12.92
# ---
# Prot: 0, y = 30.348850725218654
# y_hat_CSMA = 25.31, y_hat_TDMA = 11.72
# Evaluation: v_csma = 26.56, v_tdma = 14.88
# No. of new estimators = 10
# ---
