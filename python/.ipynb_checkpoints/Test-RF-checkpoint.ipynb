# %%
import numpy as np
from RandomForest import RandomForestSOMAC

# %%
train_file = "/Users/andre.gomes/Temp/SOMAC-ML/data/14092018/somac/backlog_file.npy"
test_file = "/Users/andre.gomes/Temp/SOMAC-ML/data/14092018/somac_1/backlog_file.npy"

# %%
test_data = np.load(test_file, encoding = "latin1").item()

# %%
rf = RandomForestSOMAC()
rf.train(train_file)

# %%
for t in range(80):
    rf.decision(test_data[t])
    print("---")
# Out:
# Confidence Interval = [0.13142011], [0.40338461]
# y_hat_sorted mean = 0.3
# Confidence Interval = [5.47930093], [6.00334274]
# y_hat_sorted mean = 5.76
# Prot: 0, y = 0.0
# y_hat_CSMA = 0.27, y_hat_TDMA = 5.74
# Evaluation: v_csma = 0.27, v_tdma = 5.74
# v_csma_ = 4, v_tdma_ = 496
# ---
# Confidence Interval = [0.33608058], [0.79152432]
# y_hat_sorted mean = 0.66
# Confidence Interval = [5.56854325], [6.08517164]
# y_hat_sorted mean = 5.86
# Prot: 1, y = 0.9482759833335876
# y_hat_CSMA = 0.56, y_hat_TDMA = 5.83
# Evaluation: v_csma = 3.51, v_tdma = 9.99
# v_csma_ = 10, v_tdma_ = 490
# ---
# Confidence Interval = [0.31010207], [0.83488894]
# y_hat_sorted mean = 0.63
# Confidence Interval = [5.97951402], [6.54870555]
# y_hat_sorted mean = 6.25
# Prot: 1, y = 2.6333330869674683
# y_hat_CSMA = 0.57, y_hat_TDMA = 6.26
# Evaluation: v_csma = 4.28, v_tdma = 9.97
# v_csma_ = 9, v_tdma_ = 491
# ---
# Confidence Interval = [0.29262436], [0.81779085]
# y_hat_sorted mean = 0.61
# Confidence Interval = [5.56854325], [6.08517164]
# y_hat_sorted mean = 5.86
# Prot: 1, y = 2.600000023841858
# y_hat_CSMA = 0.56, y_hat_TDMA = 5.83
# Evaluation: v_csma = 4.72, v_tdma = 9.23
# v_csma_ = 9, v_tdma_ = 491
# ---
# Confidence Interval = [0.30646468], [0.79512628]
# y_hat_sorted mean = 0.65
# Confidence Interval = [5.56102411], [6.07855746]
# y_hat_sorted mean = 5.85
# Prot: 1, y = 2.7827584743499756
# y_hat_CSMA = 0.55, y_hat_TDMA = 5.82
# Evaluation: v_csma = 5.04, v_tdma = 8.99
# v_csma_ = 8, v_tdma_ = 492
# ---
# Confidence Interval = [0.41107107], [1.02619464]
# y_hat_sorted mean = 0.82
# Confidence Interval = [5.47251297], [5.99733071]
# y_hat_sorted mean = 5.75
# Prot: 1, y = 2.8149425983428955
# y_hat_CSMA = 0.72, y_hat_TDMA = 5.73
# Evaluation: v_csma = 5.45, v_tdma = 8.73
# v_csma_ = 12, v_tdma_ = 488
# ---
# Confidence Interval = [3.63793873], [5.16172176]
# y_hat_sorted mean = 4.82
# Confidence Interval = [5.72944589], [6.34005184]
# y_hat_sorted mean = 6.04
# Prot: 1, y = 4.233333349227905
# y_hat_CSMA = 4.4, y_hat_TDMA = 6.03
# Evaluation: v_csma = 9.33, v_tdma = 8.88
# v_csma_ = 98, v_tdma_ = 402
# ---
# Confidence Interval = [6.06759684], [7.10275504]
# y_hat_sorted mean = 6.7
# Confidence Interval = [8.29845309], [8.76504138]
# y_hat_sorted mean = 8.58
# Prot: 1, y = 5.8833335638046265
# y_hat_CSMA = 6.59, y_hat_TDMA = 8.53
# Evaluation: v_csma = 11.68, v_tdma = 11.26
# v_csma_ = 184, v_tdma_ = 316
# ---
# Confidence Interval = [5.96792633], [7.04694777]
# y_hat_sorted mean = 6.73
# Confidence Interval = [8.29845309], [8.76504138]
# y_hat_sorted mean = 8.58
# Prot: 1, y = 5.816092014312744
# y_hat_CSMA = 6.51, y_hat_TDMA = 8.53
# Evaluation: v_csma = 11.75, v_tdma = 11.15
# v_csma_ = 177, v_tdma_ = 323
# ---
# Confidence Interval = [4.34891365], [5.32182111]
# y_hat_sorted mean = 4.94
# Confidence Interval = [8.29845309], [8.76504138]
# y_hat_sorted mean = 8.58
# Prot: 1, y = 5.78333306312561
# y_hat_CSMA = 4.84, y_hat_TDMA = 8.53
# Evaluation: v_csma = 10.2, v_tdma = 11.06
# v_csma_ = 118, v_tdma_ = 382
# ---
# Confidence Interval = [5.19956811], [6.31231714]
# y_hat_sorted mean = 5.92
# Confidence Interval = [8.22556082], [8.68922791]
# y_hat_sorted mean = 8.5
# Prot: 1, y = 5.883332967758179
# y_hat_CSMA = 5.76, y_hat_TDMA = 8.46
# Evaluation: v_csma = 11.23, v_tdma = 10.91
# v_csma_ = 161, v_tdma_ = 339
# No. of new estimators = 50
# ---
# Confidence Interval = [4.03972275], [4.95994242]
# y_hat_sorted mean = 4.53
# Confidence Interval = [7.73530266], [8.19282399]
# y_hat_sorted mean = 8.31
# Prot: 1, y = 5.7500001192092896
# y_hat_CSMA = 4.5, y_hat_TDMA = 7.96
# Evaluation: v_csma = 10.07, v_tdma = 10.34
# v_csma_ = 112, v_tdma_ = 388
# ---
# Confidence Interval = [4.78213276], [5.60562292]
# y_hat_sorted mean = 5.12
# Confidence Interval = [6.51824056], [6.93569793]
# y_hat_sorted mean = 7.01
# Prot: 1, y = 7.383333325386047
# y_hat_CSMA = 5.19, y_hat_TDMA = 6.73
# Evaluation: v_csma = 10.86, v_tdma = 9.04
# v_csma_ = 149, v_tdma_ = 351
# ---
# Confidence Interval = [6.07777673], [7.04692035]
# y_hat_sorted mean = 6.73
# Confidence Interval = [5.99972576], [6.51280576]
# y_hat_sorted mean = 6.55
# Prot: 1, y = 9.466666460037231
# y_hat_CSMA = 6.56, y_hat_TDMA = 6.26
# Evaluation: v_csma = 12.31, v_tdma = 8.51
# v_csma_ = 240, v_tdma_ = 260
# ---
# Confidence Interval = [4.69098173], [5.4995264]
# y_hat_sorted mean = 5.15
# Confidence Interval = [6.75207043], [7.25634361]
# y_hat_sorted mean = 7.16
# Prot: 1, y = 9.628735542297363
# y_hat_CSMA = 5.1, y_hat_TDMA = 7.0
# Evaluation: v_csma = 10.91, v_tdma = 9.2
# v_csma_ = 124, v_tdma_ = 376
# ---
# Confidence Interval = [5.01160102], [5.785827]
# y_hat_sorted mean = 5.53
# Confidence Interval = [6.80412626], [7.31655907]
# y_hat_sorted mean = 7.24
# Prot: 1, y = 9.68333351612091
# y_hat_CSMA = 5.4, y_hat_TDMA = 7.06
# Evaluation: v_csma = 11.29, v_tdma = 9.21
# v_csma_ = 152, v_tdma_ = 348
# ---
# Confidence Interval = [4.49329187], [5.22420768]
# y_hat_sorted mean = 4.84
# Confidence Interval = [6.72820242], [7.23659323]
# y_hat_sorted mean = 7.16
# Prot: 1, y = 9.450000405311584
# y_hat_CSMA = 4.86, y_hat_TDMA = 6.98
# Evaluation: v_csma = 10.81, v_tdma = 9.09
# v_csma_ = 119, v_tdma_ = 381
# ---
# Confidence Interval = [5.17569131], [6.01016752]
# y_hat_sorted mean = 5.75
# Confidence Interval = [6.80412626], [7.31655907]
# y_hat_sorted mean = 7.24
# Prot: 1, y = 9.500000357627869
# y_hat_CSMA = 5.59, y_hat_TDMA = 7.06
# Evaluation: v_csma = 11.6, v_tdma = 9.12
# v_csma_ = 155, v_tdma_ = 345
# ---
# Confidence Interval = [5.02572893], [5.89262296]
# y_hat_sorted mean = 5.54
# Confidence Interval = [6.61083833], [7.13584727]
# y_hat_sorted mean = 7.14
# Prot: 1, y = 11.416666984558105
# y_hat_CSMA = 5.46, y_hat_TDMA = 6.87
# Evaluation: v_csma = 11.53, v_tdma = 8.9
# v_csma_ = 152, v_tdma_ = 348
# ---
# Confidence Interval = [18.90135146], [20.52808223]
# y_hat_sorted mean = 19.47
# Confidence Interval = [7.14080468], [7.77419315]
# y_hat_sorted mean = 7.74
# Prot: 1, y = 12.76321804523468
# y_hat_CSMA = 19.71, y_hat_TDMA = 7.46
# Evaluation: v_csma = 25.83, v_tdma = 9.44
# v_csma_ = 452, v_tdma_ = 48
# ---
# Confidence Interval = [18.59571064], [20.19792133]
# y_hat_sorted mean = 19.04
# Confidence Interval = [7.1540925], [7.78598119]
# y_hat_sorted mean = 7.74
# Prot: 1, y = 13.049999594688416
# y_hat_CSMA = 19.4, y_hat_TDMA = 7.47
# Evaluation: v_csma = 25.57, v_tdma = 9.42
# v_csma_ = 455, v_tdma_ = 45
# No. of new estimators = 50
# ---
# Confidence Interval = [18.37300762], [20.00010441]
# y_hat_sorted mean = 18.78
# Confidence Interval = [8.02248103], [8.67903397]
# y_hat_sorted mean = 8.35
# Prot: 1, y = 12.737930536270142
# y_hat_CSMA = 19.19, y_hat_TDMA = 8.35
# Evaluation: v_csma = 25.4, v_tdma = 10.27
# v_csma_ = 431, v_tdma_ = 69
# ---
# Confidence Interval = [17.84815917], [19.36895312]
# y_hat_sorted mean = 18.2
# Confidence Interval = [7.698335], [8.39236647]
# y_hat_sorted mean = 8.0
# Prot: 1, y = 12.85977041721344
# y_hat_CSMA = 18.61, y_hat_TDMA = 8.05
# Evaluation: v_csma = 24.87, v_tdma = 9.93
# v_csma_ = 432, v_tdma_ = 68
# ---
# Confidence Interval = [17.79184732], [19.31817945]
# y_hat_sorted mean = 18.17
# Confidence Interval = [7.63671721], [8.31347395]
# y_hat_sorted mean = 7.91
# Prot: 1, y = 11.466666102409363
# y_hat_CSMA = 18.56, y_hat_TDMA = 7.98
# Evaluation: v_csma = 24.86, v_tdma = 9.83
# v_csma_ = 435, v_tdma_ = 65
# ---
# Confidence Interval = [16.31021864], [17.81263492]
# y_hat_sorted mean = 16.87
# Confidence Interval = [9.6689447], [10.52338363]
# y_hat_sorted mean = 10.29
# Prot: 1, y = 14.41666567325592
# y_hat_CSMA = 17.06, y_hat_TDMA = 10.1
# Evaluation: v_csma = 23.4, v_tdma = 11.93
# v_csma_ = 372, v_tdma_ = 128
# ---
# Confidence Interval = [16.98444679], [18.21417534]
# y_hat_sorted mean = 17.55
# Confidence Interval = [10.90471473], [11.79370753]
# y_hat_sorted mean = 11.41
# Prot: 1, y = 16.38793110847473
# y_hat_CSMA = 17.6, y_hat_TDMA = 11.35
# Evaluation: v_csma = 23.98, v_tdma = 13.15
# v_csma_ = 344, v_tdma_ = 156
# ---
# Confidence Interval = [18.23253313], [19.68346971]
# y_hat_sorted mean = 18.73
# Confidence Interval = [10.99518316], [11.85380009]
# y_hat_sorted mean = 11.49
# Prot: 1, y = 16.22471296787262
# y_hat_CSMA = 18.96, y_hat_TDMA = 11.42
# Evaluation: v_csma = 25.38, v_tdma = 13.2
# v_csma_ = 359, v_tdma_ = 141
# ---
# Confidence Interval = [18.48843996], [19.8032195]
# y_hat_sorted mean = 19.11
# Confidence Interval = [10.88156809], [11.75896225]
# y_hat_sorted mean = 11.38
# Prot: 1, y = 16.52126443386078
# y_hat_CSMA = 19.15, y_hat_TDMA = 11.32
# Evaluation: v_csma = 25.6, v_tdma = 13.08
# v_csma_ = 365, v_tdma_ = 135
# ---
# Confidence Interval = [18.363054], [19.82273447]
# y_hat_sorted mean = 18.89
# Confidence Interval = [10.96492693], [11.82565632]
# y_hat_sorted mean = 11.49
# Prot: 1, y = 15.051149010658264
# y_hat_CSMA = 19.09, y_hat_TDMA = 11.4
# Evaluation: v_csma = 25.58, v_tdma = 13.13
# v_csma_ = 360, v_tdma_ = 140
# ---
# Confidence Interval = [16.58608616], [17.95510182]
# y_hat_sorted mean = 17.1
# Confidence Interval = [10.96492693], [11.82565632]
# y_hat_sorted mean = 11.49
# Prot: 1, y = 16.499999046325684
# y_hat_CSMA = 17.27, y_hat_TDMA = 11.4
# Evaluation: v_csma = 23.79, v_tdma = 13.11
# v_csma_ = 339, v_tdma_ = 161
# ---
# Confidence Interval = [19.5058587], [20.83243985]
# y_hat_sorted mean = 20.02
# Confidence Interval = [10.99518316], [11.85380009]
# y_hat_sorted mean = 11.49
# Prot: 1, y = 18.612643599510193
# y_hat_CSMA = 20.17, y_hat_TDMA = 11.42
# Evaluation: v_csma = 26.72, v_tdma = 13.12
# v_csma_ = 392, v_tdma_ = 108
# No. of new estimators = 50
# ---
# Confidence Interval = [27.85854561], [28.58641352]
# y_hat_sorted mean = 28.09
# Confidence Interval = [12.38869198], [13.17709586]
# y_hat_sorted mean = 13.18
# Prot: 1, y = 19.648850083351135
# y_hat_CSMA = 28.22, y_hat_TDMA = 12.78
# Evaluation: v_csma = 34.8, v_tdma = 14.45
# v_csma_ = 490, v_tdma_ = 10
# ---
# Confidence Interval = [27.99316082], [28.72166836]
# y_hat_sorted mean = 28.23
# Confidence Interval = [12.41186707], [13.19754145]
# y_hat_sorted mean = 13.21
# Prot: 1, y = 19.72701144218445
# y_hat_CSMA = 28.36, y_hat_TDMA = 12.8
# Evaluation: v_csma = 34.97, v_tdma = 14.46
# v_csma_ = 491, v_tdma_ = 9
# ---
# Confidence Interval = [26.90734799], [27.68253158]
# y_hat_sorted mean = 27.09
# Confidence Interval = [12.41944351], [13.20533973]
# y_hat_sorted mean = 13.18
# Prot: 1, y = 19.233333230018616
# y_hat_CSMA = 27.29, y_hat_TDMA = 12.81
# Evaluation: v_csma = 33.93, v_tdma = 14.45
# v_csma_ = 488, v_tdma_ = 12
# ---
# Confidence Interval = [25.97841826], [27.06778907]
# y_hat_sorted mean = 26.29
# Confidence Interval = [12.35837487], [13.15576008]
# y_hat_sorted mean = 13.1
# Prot: 1, y = 19.99999988079071
# y_hat_CSMA = 26.52, y_hat_TDMA = 12.76
# Evaluation: v_csma = 33.19, v_tdma = 14.37
# v_csma_ = 473, v_tdma_ = 27
# ---
# Confidence Interval = [28.05006101], [28.76128403]
# y_hat_sorted mean = 28.27
# Confidence Interval = [12.38869198], [13.17709586]
# y_hat_sorted mean = 13.18
# Prot: 1, y = 19.300000190734863
# y_hat_CSMA = 28.41, y_hat_TDMA = 12.78
# Evaluation: v_csma = 35.1, v_tdma = 14.38
# v_csma_ = 491, v_tdma_ = 9
# ---
# Confidence Interval = [29.93381753], [30.44060442]
# y_hat_sorted mean = 30.14
# Confidence Interval = [11.83623764], [12.72889725]
# y_hat_sorted mean = 12.66
# Prot: 1, y = 20.766666531562805
# y_hat_CSMA = 30.19, y_hat_TDMA = 12.28
# Evaluation: v_csma = 36.91, v_tdma = 13.87
# v_csma_ = 500, v_tdma_ = 0
# ---
# Confidence Interval = [20.71825519], [21.66770618]
# y_hat_sorted mean = 21.18
# Confidence Interval = [12.38869198], [13.17709586]
# y_hat_sorted mean = 13.18
# Prot: 1, y = 22.152873992919922
# y_hat_CSMA = 21.19, y_hat_TDMA = 12.78
# Evaluation: v_csma = 27.94, v_tdma = 14.35
# v_csma_ = 488, v_tdma_ = 12
# ---
# Confidence Interval = [20.42326294], [21.29702254]
# y_hat_sorted mean = 20.99
# Confidence Interval = [12.21577975], [13.04878962]
# y_hat_sorted mean = 13.1
# Prot: 1, y = 22.166667461395264
# y_hat_CSMA = 20.86, y_hat_TDMA = 12.63
# Evaluation: v_csma = 27.63, v_tdma = 14.18
# v_csma_ = 493, v_tdma_ = 7
# ---
# Confidence Interval = [20.54338455], [21.50613097]
# y_hat_sorted mean = 21.1
# Confidence Interval = [12.21577975], [13.04878962]
# y_hat_sorted mean = 13.1
# Prot: 1, y = 21.8735631108284
# y_hat_CSMA = 21.02, y_hat_TDMA = 12.63
# Evaluation: v_csma = 27.82, v_tdma = 14.17
# v_csma_ = 488, v_tdma_ = 12
# ---
# Confidence Interval = [20.82005223], [21.70995675]
# y_hat_sorted mean = 21.29
# Confidence Interval = [12.41944351], [13.20533973]
# y_hat_sorted mean = 13.18
# Prot: 1, y = 21.692529022693634
# y_hat_CSMA = 21.27, y_hat_TDMA = 12.81
# Evaluation: v_csma = 28.08, v_tdma = 14.34
# v_csma_ = 490, v_tdma_ = 10
# No. of new estimators = 50
# ---
# Confidence Interval = [20.62925745], [21.5672757]
# y_hat_sorted mean = 21.1
# Confidence Interval = [14.07676237], [14.85146005]
# y_hat_sorted mean = 14.54
# Prot: 1, y = 21.906896233558655
# y_hat_CSMA = 21.1, y_hat_TDMA = 14.46
# Evaluation: v_csma = 27.93, v_tdma = 15.97
# v_csma_ = 452, v_tdma_ = 48
# ---
# Confidence Interval = [20.86620319], [21.84632583]
# y_hat_sorted mean = 21.42
# Confidence Interval = [14.08256345], [14.8523141]
# y_hat_sorted mean = 14.56
# Prot: 1, y = 24.329883694648743
# y_hat_CSMA = 21.36, y_hat_TDMA = 14.47
# Evaluation: v_csma = 28.21, v_tdma = 15.96
# v_csma_ = 451, v_tdma_ = 49
# ---
# Confidence Interval = [20.76676722], [21.71498586]
# y_hat_sorted mean = 21.3
# Confidence Interval = [14.10805719], [14.87406172]
# y_hat_sorted mean = 14.59
# Prot: 1, y = 25.229310989379883
# y_hat_CSMA = 21.24, y_hat_TDMA = 14.49
# Evaluation: v_csma = 28.12, v_tdma = 15.97
# v_csma_ = 452, v_tdma_ = 48
# ---
# Confidence Interval = [20.77057517], [21.7084247]
# y_hat_sorted mean = 21.3
# Confidence Interval = [14.0971285], [14.86603411]
# y_hat_sorted mean = 14.58
# Prot: 1, y = 26.039655447006226
# y_hat_CSMA = 21.24, y_hat_TDMA = 14.48
# Evaluation: v_csma = 28.14, v_tdma = 15.95
# v_csma_ = 452, v_tdma_ = 48
# ---
# Confidence Interval = [20.78578218], [21.75851527]
# y_hat_sorted mean = 21.36
# Confidence Interval = [13.84798499], [14.66995226]
# y_hat_sorted mean = 14.35
# Prot: 1, y = 25.522414088249207
# y_hat_CSMA = 21.27, y_hat_TDMA = 14.26
# Evaluation: v_csma = 28.19, v_tdma = 15.72
# v_csma_ = 450, v_tdma_ = 50
# ---
# Confidence Interval = [20.78578218], [21.75851527]
# y_hat_sorted mean = 21.36
# Confidence Interval = [13.84798499], [14.66995226]
# y_hat_sorted mean = 14.35
# Prot: 1, y = 25.885056495666504
# y_hat_CSMA = 21.27, y_hat_TDMA = 14.26
# Evaluation: v_csma = 28.21, v_tdma = 15.71
# v_csma_ = 450, v_tdma_ = 50
# ---
# Confidence Interval = [20.63386618], [21.56017248]
# y_hat_sorted mean = 21.11
# Confidence Interval = [14.0971285], [14.86603411]
# y_hat_sorted mean = 14.58
# Prot: 1, y = 25.633906960487366
# y_hat_CSMA = 21.1, y_hat_TDMA = 14.48
# Evaluation: v_csma = 28.05, v_tdma = 15.92
# v_csma_ = 453, v_tdma_ = 47
# ---
# Confidence Interval = [20.89478413], [21.8844627]
# y_hat_sorted mean = 21.45
# Confidence Interval = [14.08256345], [14.8523141]
# y_hat_sorted mean = 14.56
# Prot: 1, y = 25.416666507720947
# y_hat_CSMA = 21.39, y_hat_TDMA = 14.47
# Evaluation: v_csma = 28.36, v_tdma = 15.89
# v_csma_ = 451, v_tdma_ = 49
# ---
# Confidence Interval = [1.73305571], [2.49686749]
# y_hat_sorted mean = 2.02
# Confidence Interval = [10.05642566], [10.77709641]
# y_hat_sorted mean = 9.63
# Prot: 1, y = 21.498276710510254
# y_hat_CSMA = 2.11, y_hat_TDMA = 10.42
# Evaluation: v_csma = 9.11, v_tdma = 11.83
# v_csma_ = 36, v_tdma_ = 464
# ---
# Confidence Interval = [1.59027183], [2.73173109]
# y_hat_sorted mean = 2.41
# Confidence Interval = [7.36544767], [8.23399705]
# y_hat_sorted mean = 6.63
# Prot: 1, y = 4.81666699051857
# y_hat_CSMA = 2.16, y_hat_TDMA = 7.8
# Evaluation: v_csma = 9.17, v_tdma = 9.2
# v_csma_ = 41, v_tdma_ = 459
# No. of new estimators = 50
# ---
# Confidence Interval = [0.66027243], [1.4255819]
# y_hat_sorted mean = 1.16
# Confidence Interval = [7.92800062], [8.98016949]
# y_hat_sorted mean = 8.07
# Prot: 1, y = 3.25
# y_hat_CSMA = 1.04, y_hat_TDMA = 8.45
# Evaluation: v_csma = 8.07, v_tdma = 9.85
# v_csma_ = 18, v_tdma_ = 482
# ---
# Confidence Interval = [0.60234397], [1.32424112]
# y_hat_sorted mean = 1.14
# Confidence Interval = [8.03702525], [9.0826046]
# y_hat_sorted mean = 8.16
# Prot: 1, y = 3.616666555404663
# y_hat_CSMA = 0.96, y_hat_TDMA = 8.56
# Evaluation: v_csma = 8.01, v_tdma = 9.94
# v_csma_ = 19, v_tdma_ = 481
# ---
# Confidence Interval = [0.45090292], [1.06480834]
# y_hat_sorted mean = 0.86
# Confidence Interval = [7.68662405], [8.68551615]
# y_hat_sorted mean = 8.13
# Prot: 1, y = 3.649999976158142
# y_hat_CSMA = 0.76, y_hat_TDMA = 8.19
# Evaluation: v_csma = 7.82, v_tdma = 9.56
# v_csma_ = 12, v_tdma_ = 488
# ---
# Confidence Interval = [0.4866559], [1.15095645]
# y_hat_sorted mean = 0.93
# Confidence Interval = [7.8629728], [8.89949387]
# y_hat_sorted mean = 8.08
# Prot: 1, y = 3.4833329916000366
# y_hat_CSMA = 0.82, y_hat_TDMA = 8.38
# Evaluation: v_csma = 7.9, v_tdma = 9.74
# v_csma_ = 13, v_tdma_ = 487
# ---
# Confidence Interval = [7.90560365], [9.34383529]
# y_hat_sorted mean = 8.71
# Confidence Interval = [8.79140719], [9.76119764]
# y_hat_sorted mean = 8.94
# Prot: 1, y = 5.733333587646484
# y_hat_CSMA = 8.62, y_hat_TDMA = 9.28
# Evaluation: v_csma = 15.72, v_tdma = 10.63
# v_csma_ = 218, v_tdma_ = 282
# ---
# Confidence Interval = [6.04394962], [7.24237515]
# y_hat_sorted mean = 6.75
# Confidence Interval = [10.10775852], [10.98340941]
# y_hat_sorted mean = 10.37
# Prot: 1, y = 5.800000548362732
# y_hat_CSMA = 6.64, y_hat_TDMA = 10.55
# Evaluation: v_csma = 13.75, v_tdma = 11.89
# v_csma_ = 137, v_tdma_ = 363
# ---
# Confidence Interval = [5.07107738], [6.07848506]
# y_hat_sorted mean = 5.64
# Confidence Interval = [10.06197805], [10.94411632]
# y_hat_sorted mean = 10.32
# Prot: 1, y = 5.839655041694641
# y_hat_CSMA = 5.57, y_hat_TDMA = 10.5
# Evaluation: v_csma = 12.7, v_tdma = 11.84
# v_csma_ = 141, v_tdma_ = 359
# ---
# Confidence Interval = [7.01381715], [7.981372]
# y_hat_sorted mean = 7.6
# Confidence Interval = [9.989095], [10.90502495]
# y_hat_sorted mean = 10.32
# Prot: 1, y = 5.883333086967468
# y_hat_CSMA = 7.5, y_hat_TDMA = 10.45
# Evaluation: v_csma = 14.64, v_tdma = 11.77
# v_csma_ = 186, v_tdma_ = 314
# ---
# Confidence Interval = [7.12378284], [8.08661716]
# y_hat_sorted mean = 7.65
# Confidence Interval = [9.989095], [10.90502495]
# y_hat_sorted mean = 10.32
# Prot: 1, y = 5.916666507720947
# y_hat_CSMA = 7.61, y_hat_TDMA = 10.45
# Evaluation: v_csma = 14.76, v_tdma = 11.76
# v_csma_ = 190, v_tdma_ = 310
# ---
# Confidence Interval = [5.01139872], [5.9950204]
# y_hat_sorted mean = 5.55
# Confidence Interval = [9.77214666], [10.62084196]
# y_hat_sorted mean = 10.32
# Prot: 1, y = 5.7500001192092896
# y_hat_CSMA = 5.5, y_hat_TDMA = 10.2
# Evaluation: v_csma = 12.67, v_tdma = 11.51
# v_csma_ = 144, v_tdma_ = 356
# No. of new estimators = 50
# ---
# Confidence Interval = [5.54718512], [6.32506771]
# y_hat_sorted mean = 6.01
# Confidence Interval = [9.12456009], [9.88858989]
# y_hat_sorted mean = 9.11
# Prot: 1, y = 9.083333492279053
# y_hat_CSMA = 5.94, y_hat_TDMA = 9.51
# Evaluation: v_csma = 13.12, v_tdma = 10.81
# v_csma_ = 103, v_tdma_ = 397
# ---
# Confidence Interval = [4.84652274], [5.68051549]
# y_hat_sorted mean = 5.33
# Confidence Interval = [9.19488928], [9.94295243]
# y_hat_sorted mean = 9.18
# Prot: 1, y = 9.079309940338135
# y_hat_CSMA = 5.26, y_hat_TDMA = 9.57
# Evaluation: v_csma = 12.46, v_tdma = 10.86
# v_csma_ = 71, v_tdma_ = 429
# ---
# Confidence Interval = [6.11280862], [7.38343715]
# y_hat_sorted mean = 6.95
# Confidence Interval = [9.25253565], [9.99852674]
# y_hat_sorted mean = 9.25
# Prot: 1, y = 9.056897044181824
# y_hat_CSMA = 6.75, y_hat_TDMA = 9.63
# Evaluation: v_csma = 13.96, v_tdma = 10.91
# v_csma_ = 96, v_tdma_ = 404
# ---
# Confidence Interval = [5.35695725], [6.45784655]
# y_hat_sorted mean = 5.91
# Confidence Interval = [9.11560881], [9.85369495]
# y_hat_sorted mean = 9.11
# Prot: 1, y = 9.333333969116211
# y_hat_CSMA = 5.91, y_hat_TDMA = 9.48
# Evaluation: v_csma = 13.13, v_tdma = 10.76
# v_csma_ = 78, v_tdma_ = 422
# ---
# Confidence Interval = [4.85123412], [5.68466362]
# y_hat_sorted mean = 5.33
# Confidence Interval = [9.18548016], [9.93354549]
# y_hat_sorted mean = 9.16
# Prot: 1, y = 9.166666507720947
# y_hat_CSMA = 5.27, y_hat_TDMA = 9.56
# Evaluation: v_csma = 12.5, v_tdma = 10.83
# v_csma_ = 71, v_tdma_ = 429
# ---
# Confidence Interval = [6.5281222], [7.82181524]
# y_hat_sorted mean = 7.45
# Confidence Interval = [9.23728344], [9.98138813]
# y_hat_sorted mean = 9.24
# Prot: 1, y = 9.149999499320984
# y_hat_CSMA = 7.17, y_hat_TDMA = 9.61
# Evaluation: v_csma = 14.42, v_tdma = 10.87
# v_csma_ = 108, v_tdma_ = 392
# ---
# Confidence Interval = [21.43364641], [23.02543841]
# y_hat_sorted mean = 22.15
# Confidence Interval = [9.87604715], [10.68801732]
# y_hat_sorted mean = 10.07
# Prot: 1, y = 12.8166663646698
# y_hat_CSMA = 22.23, y_hat_TDMA = 10.28
# Evaluation: v_csma = 29.49, v_tdma = 11.54
# v_csma_ = 441, v_tdma_ = 59
# ---
# Confidence Interval = [18.59166866], [20.1961195]
# y_hat_sorted mean = 19.03
# Confidence Interval = [10.07216864], [10.89705669]
# y_hat_sorted mean = 10.3
# Prot: 1, y = 12.616666436195374
# y_hat_CSMA = 19.39, y_hat_TDMA = 10.48
# Evaluation: v_csma = 26.67, v_tdma = 11.73
# v_csma_ = 404, v_tdma_ = 96
# ---
# Confidence Interval = [17.84815917], [19.36895312]
# y_hat_sorted mean = 18.2
# Confidence Interval = [9.85642588], [10.72545032]
# y_hat_sorted mean = 10.06
# Prot: 1, y = 12.716666996479034
# y_hat_CSMA = 18.61, y_hat_TDMA = 10.29
# Evaluation: v_csma = 25.9, v_tdma = 11.53
# v_csma_ = 397, v_tdma_ = 103
# ---
# Confidence Interval = [18.45594781], [20.08820684]
# y_hat_sorted mean = 19.04
# Confidence Interval = [10.07076801], [10.89548957]
# y_hat_sorted mean = 10.3
# Prot: 1, y = 13.375862181186676
# y_hat_CSMA = 19.27, y_hat_TDMA = 10.48
# Evaluation: v_csma = 26.57, v_tdma = 11.72
# v_csma_ = 399, v_tdma_ = 101
# No. of new estimators = 50
# ---
# Confidence Interval = [18.5807811], [20.1794264]
# y_hat_sorted mean = 19.02
# Confidence Interval = [9.73159434], [10.38400798]
# y_hat_sorted mean = 10.45
# Prot: 1, y = 12.733333468437195
# y_hat_CSMA = 19.38, y_hat_TDMA = 10.06
# Evaluation: v_csma = 26.69, v_tdma = 11.28
# v_csma_ = 398, v_tdma_ = 102
# ---
# Confidence Interval = [17.86838344], [19.41909822]
# y_hat_sorted mean = 18.28
# Confidence Interval = [9.49015096], [10.16429534]
# y_hat_sorted mean = 10.16
# Prot: 1, y = 12.666666626930237
# y_hat_CSMA = 18.64, y_hat_TDMA = 9.83
# Evaluation: v_csma = 25.97, v_tdma = 11.05
# v_csma_ = 398, v_tdma_ = 102
# ---
# Confidence Interval = [17.60550184], [18.93265778]
# y_hat_sorted mean = 18.09
# Confidence Interval = [13.07564192], [13.77462871]
# y_hat_sorted mean = 13.12
# Prot: 1, y = 15.70000010728836
# y_hat_CSMA = 18.27, y_hat_TDMA = 13.43
# Evaluation: v_csma = 25.6, v_tdma = 14.64
# v_csma_ = 305, v_tdma_ = 195
# ---
# Confidence Interval = [18.60687174], [19.9337866]
# y_hat_sorted mean = 19.19
# Confidence Interval = [13.07104762], [13.78058849]
# y_hat_sorted mean = 13.13
# Prot: 1, y = 16.20459759235382
# y_hat_CSMA = 19.27, y_hat_TDMA = 13.43
# Evaluation: v_csma = 26.62, v_tdma = 14.63
# v_csma_ = 325, v_tdma_ = 175
# ---
# Confidence Interval = [18.61044586], [19.94222479]
# y_hat_sorted mean = 19.11
# Confidence Interval = [13.0719419], [13.77025748]
# y_hat_sorted mean = 13.12
# Prot: 1, y = 15.909196078777313
# y_hat_CSMA = 19.28, y_hat_TDMA = 13.42
# Evaluation: v_csma = 26.63, v_tdma = 14.62
# v_csma_ = 325, v_tdma_ = 175
# ---
# Confidence Interval = [18.33818044], [19.78934806]
# y_hat_sorted mean = 18.86
# Confidence Interval = [13.1071522], [13.79462883]
# y_hat_sorted mean = 13.17
# Prot: 1, y = 16.333333492279053
# y_hat_CSMA = 19.06, y_hat_TDMA = 13.45
# Evaluation: v_csma = 26.43, v_tdma = 14.65
# v_csma_ = 325, v_tdma_ = 175
# ---
# Confidence Interval = [16.92389923], [18.14459617]
# y_hat_sorted mean = 17.51
# Confidence Interval = [13.00144433], [13.71140327]
# y_hat_sorted mean = 13.04
# Prot: 1, y = 16.228735983371735
# y_hat_CSMA = 17.53, y_hat_TDMA = 13.36
# Evaluation: v_csma = 24.91, v_tdma = 14.55
# v_csma_ = 299, v_tdma_ = 201
# ---
# Confidence Interval = [16.98720042], [18.31386865]
# y_hat_sorted mean = 17.52
# Confidence Interval = [13.13549185], [13.81760408]
# y_hat_sorted mean = 13.2
# Prot: 1, y = 15.766667068004608
# y_hat_CSMA = 17.65, y_hat_TDMA = 13.48
# Evaluation: v_csma = 25.04, v_tdma = 14.66
# v_csma_ = 298, v_tdma_ = 202
# ---
# Confidence Interval = [28.12718741], [28.86909245]
# y_hat_sorted mean = 28.39
# Confidence Interval = [13.18479016], [13.90525746]
# y_hat_sorted mean = 13.27
# Prot: 1, y = 18.549999713897705
# y_hat_CSMA = 28.5, y_hat_TDMA = 13.55
# Evaluation: v_csma = 35.9, v_tdma = 14.72
# v_csma_ = 483, v_tdma_ = 17
# ---
