# %%
import numpy as np
from RandomForest import RandomForest
from EsembleNNet import EsembleNNet
from SOMAC import SOMAC
# Out:
# /usr/local/lib/python3.7/site-packages/sklearn/ensemble/weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %%
train_file = "/Users/andre.gomes/Temp/SOMAC-ML/data/14092018/somac/training_file.npy"
test_file = "/Users/andre.gomes/Temp/SOMAC-ML/data/14092018/somac/backlog_file.npy"

# %%
test_data = np.load(test_file, encoding = "latin1").item()

# %%
# somac = SOMAC(reg_csma = RandomForest(), reg_tdma = EsembleNNet())
# EsembleNNet(n_new_estimators = 10, n_neurons = 3)
somac = SOMAC(reg_csma = EsembleNNet(n_new_estimators = 10, n_neurons = 3, bag_size = 1),
              reg_tdma = EsembleNNet(n_new_estimators = 10, n_neurons = 3, bag_size = 1))
somac.train(train_file)

# %%
for t in range(80):
    somac.decision(test_data[t])
    y = test_data[t]["metrics"][0, 1]
    prot = test_data[t]["prot"]
    print("---")
# Out:
# Prot: 0, y = 0.16666649281978607
# y_hat_CSMA = -12.91, y_hat_TDMA = -2.51
# Evaluation: v_csma = -12.91, v_tdma = -2.51
# ---
# Prot: 0, y = 0.2758620008826256
# y_hat_CSMA = -11.81, y_hat_TDMA = -1.02
# Evaluation: v_csma = -8.86, v_tdma = 3.14
# ---
# Prot: 0, y = 0.1189655028283596
# y_hat_CSMA = 0.18, y_hat_TDMA = 0.41
# Evaluation: v_csma = 3.21, v_tdma = 5.65
# ---
# Prot: 0, y = 0.05000000074505806
# y_hat_CSMA = 2.43, y_hat_TDMA = 0.15
# Evaluation: v_csma = 5.37, v_tdma = 6.03
# ---
# Prot: 0, y = 0.03333349898457527
# y_hat_CSMA = 19.52, y_hat_TDMA = 2.49
# Evaluation: v_csma = 22.36, v_tdma = 8.83
# ---
# Prot: 0, y = 0.1333335041999817
# y_hat_CSMA = 19.66, y_hat_TDMA = 2.5
# Evaluation: v_csma = 22.4, v_tdma = 9.19
# ---
# Prot: 0, y = 0.20000000298023224
# y_hat_CSMA = 19.79, y_hat_TDMA = 2.51
# Evaluation: v_csma = 22.43, v_tdma = 9.49
# ---
# Prot: 0, y = 0.4166665133088827
# y_hat_CSMA = 22.69, y_hat_TDMA = 3.75
# Evaluation: v_csma = 25.24, v_tdma = 10.96
# ---
# Prot: 0, y = 0.1333335041999817
# y_hat_CSMA = 21.21, y_hat_TDMA = 3.64
# Evaluation: v_csma = 23.68, v_tdma = 11.06
# ---
# Prot: 0, y = 0.4735630042850971
# y_hat_CSMA = 23.01, y_hat_TDMA = 4.98
# Evaluation: v_csma = 25.41, v_tdma = 12.57
# No. of new estimators = 10
# ---
# Prot: 0, y = 0.30000000447034836
# y_hat_CSMA = 19.08, y_hat_TDMA = 3.81
# Evaluation: v_csma = 21.41, v_tdma = 11.55
# ---
# Prot: 1, y = 2.133333493024111
# y_hat_CSMA = 18.71, y_hat_TDMA = 3.76
# Evaluation: v_csma = 20.98, v_tdma = 11.64
# ---
# Prot: 1, y = 6.916666865348816
# y_hat_CSMA = 21.58, y_hat_TDMA = 5.13
# Evaluation: v_csma = 23.89, v_tdma = 10.79
# ---
# Prot: 0, y = 8.033333539962769
# y_hat_CSMA = 23.15, y_hat_TDMA = 7.51
# Evaluation: v_csma = 25.49, v_tdma = 12.2
# ---
# Prot: 0, y = 0.3166665006428957
# y_hat_CSMA = 19.37, y_hat_TDMA = 3.9
# Evaluation: v_csma = 21.65, v_tdma = 8.65
# ---
# Prot: 1, y = 4.100000007078052
# y_hat_CSMA = 23.21, y_hat_TDMA = 8.09
# Evaluation: v_csma = 25.43, v_tdma = 12.89
# ---
# Prot: 0, y = 7.051723822951317
# y_hat_CSMA = 23.3, y_hat_TDMA = 8.07
# Evaluation: v_csma = 25.55, v_tdma = 12.28
# ---
# Prot: 0, y = 0.733333021402359
# y_hat_CSMA = 22.97, y_hat_TDMA = 8.14
# Evaluation: v_csma = 25.16, v_tdma = 12.39
# ---
# Prot: 0, y = 1.8166670091450214
# y_hat_CSMA = 21.34, y_hat_TDMA = 5.08
# Evaluation: v_csma = 23.48, v_tdma = 9.37
# ---
# Prot: 0, y = 2.916666530072689
# y_hat_CSMA = 24.48, y_hat_TDMA = 10.7
# Evaluation: v_csma = 26.57, v_tdma = 15.03
# ---
# Prot: 0, y = 1.4999990034848452
# y_hat_CSMA = 25.03, y_hat_TDMA = 10.91
# Evaluation: v_csma = 27.09, v_tdma = 15.27
# ---
# Prot: 0, y = 1.8333329912275076
# y_hat_CSMA = 23.37, y_hat_TDMA = 9.49
# Evaluation: v_csma = 25.39, v_tdma = 13.89
# ---
# Prot: 0, y = 2.883333060890436
# y_hat_CSMA = 22.46, y_hat_TDMA = 7.49
# Evaluation: v_csma = 24.44, v_tdma = 11.92
# No. of new estimators = 10
# ---
# Prot: 0, y = 0.9028739891946316
# y_hat_CSMA = 21.81, y_hat_TDMA = 9.61
# Evaluation: v_csma = 23.76, v_tdma = 14.06
# ---
# Prot: 0, y = 4.910919472575188
# y_hat_CSMA = 21.05, y_hat_TDMA = 7.86
# Evaluation: v_csma = 22.96, v_tdma = 12.35
# ---
# Prot: 0, y = 10.743678409606218
# y_hat_CSMA = 25.65, y_hat_TDMA = 11.59
# Evaluation: v_csma = 27.53, v_tdma = 16.1
# ---
# Prot: 0, y = 9.882758498191833
# y_hat_CSMA = 25.24, y_hat_TDMA = 9.78
# Evaluation: v_csma = 27.09, v_tdma = 14.32
# ---
# Prot: 0, y = 9.949999988079071
# y_hat_CSMA = 22.45, y_hat_TDMA = 10.82
# Evaluation: v_csma = 24.27, v_tdma = 15.39
# ---
# Prot: 0, y = 8.91781634092331
# y_hat_CSMA = 22.42, y_hat_TDMA = 10.83
# Evaluation: v_csma = 24.22, v_tdma = 15.41
# ---
# Prot: 0, y = 8.383908420801163
# y_hat_CSMA = 23.76, y_hat_TDMA = 8.57
# Evaluation: v_csma = 25.54, v_tdma = 13.18
# ---
# Prot: 0, y = 11.750000514090061
# y_hat_CSMA = 24.85, y_hat_TDMA = 10.68
# Evaluation: v_csma = 26.61, v_tdma = 15.31
# ---
# Prot: 0, y = 14.724713265895844
# y_hat_CSMA = 27.08, y_hat_TDMA = 11.67
# Evaluation: v_csma = 28.81, v_tdma = 16.33
# ---
# Prot: 0, y = 13.083333998918533
# y_hat_CSMA = 26.44, y_hat_TDMA = 11.36
# Evaluation: v_csma = 28.14, v_tdma = 16.04
# No. of new estimators = 10
# ---
# Prot: 0, y = 17.635632053017616
# y_hat_CSMA = 23.37, y_hat_TDMA = 11.35
# Evaluation: v_csma = 25.06, v_tdma = 16.04
# ---
# Prot: 0, y = 15.716667026281357
# y_hat_CSMA = 24.51, y_hat_TDMA = 13.01
# Evaluation: v_csma = 26.17, v_tdma = 17.73
# ---
# Prot: 0, y = 17.36666637659073
# y_hat_CSMA = 20.48, y_hat_TDMA = 8.84
# Evaluation: v_csma = 22.13, v_tdma = 13.57
# ---
# Prot: 1, y = 16.383907187730074
# y_hat_CSMA = 25.72, y_hat_TDMA = 13.17
# Evaluation: v_csma = 27.35, v_tdma = 17.92
# ---
# Prot: 0, y = 16.57356345653534
# y_hat_CSMA = 26.59, y_hat_TDMA = 18.03
# Evaluation: v_csma = 28.22, v_tdma = 22.29
# ---
# Prot: 0, y = 24.733333542943
# y_hat_CSMA = 24.98, y_hat_TDMA = 16.85
# Evaluation: v_csma = 26.6, v_tdma = 21.13
# ---
# Prot: 0, y = 24.066666461527348
# y_hat_CSMA = 24.87, y_hat_TDMA = 16.59
# Evaluation: v_csma = 26.47, v_tdma = 20.88
# ---
# Prot: 0, y = 18.854023329913616
# y_hat_CSMA = 26.36, y_hat_TDMA = 17.99
# Evaluation: v_csma = 27.94, v_tdma = 22.3
# ---
# Prot: 0, y = 24.756321247667074
# y_hat_CSMA = 24.7, y_hat_TDMA = 15.79
# Evaluation: v_csma = 26.27, v_tdma = 20.12
# ---
# Prot: 0, y = 26.100000955164433
# y_hat_CSMA = 25.86, y_hat_TDMA = 16.34
# Evaluation: v_csma = 27.42, v_tdma = 20.68
# ---
# Prot: 0, y = 29.66494370996952
# y_hat_CSMA = 25.88, y_hat_TDMA = 14.79
# Evaluation: v_csma = 27.42, v_tdma = 19.14
# No. of new estimators = 10
# ---
# Prot: 0, y = 29.97586240619421
# y_hat_CSMA = 22.66, y_hat_TDMA = 15.77
# Evaluation: v_csma = 24.19, v_tdma = 20.13
# ---
# Prot: 0, y = 29.785631518810987
# y_hat_CSMA = 23.29, y_hat_TDMA = 16.9
# Evaluation: v_csma = 24.8, v_tdma = 21.28
# ---
# Prot: 0, y = 31.40287342481315
# y_hat_CSMA = 22.59, y_hat_TDMA = 14.06
# Evaluation: v_csma = 24.08, v_tdma = 18.45
# ---
# Prot: 0, y = 33.03735616616905
# y_hat_CSMA = 23.19, y_hat_TDMA = 15.37
# Evaluation: v_csma = 24.67, v_tdma = 19.77
# ---
# Prot: 0, y = 25.86896612495184
# y_hat_CSMA = 23.12, y_hat_TDMA = 15.58
# Evaluation: v_csma = 24.59, v_tdma = 19.99
# ---
# Prot: 0, y = 15.201149892061949
# y_hat_CSMA = 12.3, y_hat_TDMA = 11.05
# Evaluation: v_csma = 13.76, v_tdma = 15.47
# ---
# Prot: 1, y = 10.529310837388039
# y_hat_CSMA = 9.25, y_hat_TDMA = 8.91
# Evaluation: v_csma = 10.7, v_tdma = 13.35
# ---
# Prot: 1, y = 11.864367604255676
# y_hat_CSMA = 10.36, y_hat_TDMA = 6.62
# Evaluation: v_csma = 11.81, v_tdma = 10.67
# ---
# Prot: 1, y = 5.138505503535271
# y_hat_CSMA = 11.19, y_hat_TDMA = 2.76
# Evaluation: v_csma = 12.64, v_tdma = 6.52
# ---
# Prot: 1, y = 3.716666579246521
# y_hat_CSMA = 11.28, y_hat_TDMA = 2.48
# Evaluation: v_csma = 12.74, v_tdma = 6.01
# ---
# Prot: 1, y = 3.649999976158142
# y_hat_CSMA = 11.27, y_hat_TDMA = 2.54
# Evaluation: v_csma = 12.73, v_tdma = 5.88
# ---
# Prot: 1, y = 6.71666693687439
# y_hat_CSMA = 13.44, y_hat_TDMA = 3.25
# Evaluation: v_csma = 14.91, v_tdma = 6.42
# No. of new estimators = 10
# ---
# Prot: 0, y = 10.90114951133728
# y_hat_CSMA = 13.87, y_hat_TDMA = 4.66
# Evaluation: v_csma = 15.33, v_tdma = 7.69
# ---
# Prot: 0, y = 17.21666669845581
# y_hat_CSMA = 13.94, y_hat_TDMA = 3.6
# Evaluation: v_csma = 15.4, v_tdma = 6.63
# ---
# Prot: 0, y = 19.53333330154419
# y_hat_CSMA = 13.72, y_hat_TDMA = 2.56
# Evaluation: v_csma = 15.16, v_tdma = 5.61
# ---
# Prot: 0, y = 19.409769535064697
# y_hat_CSMA = 13.53, y_hat_TDMA = 0.76
# Evaluation: v_csma = 14.96, v_tdma = 3.81
# No. of new estimators = 10
# ---
# Prot: 0, y = 16.149999618530273
# y_hat_CSMA = 15.24, y_hat_TDMA = 1.17
# Evaluation: v_csma = 16.66, v_tdma = 4.23
# ---
# Prot: 0, y = 24.96666646003723
# y_hat_CSMA = 17.67, y_hat_TDMA = 0.23
# Evaluation: v_csma = 19.08, v_tdma = 3.29
# ---
# Prot: 0, y = 25.166666507720947
# y_hat_CSMA = 17.76, y_hat_TDMA = 0.13
# Evaluation: v_csma = 19.15, v_tdma = 3.2
# ---
# Prot: 0, y = 25.68333339691162
# y_hat_CSMA = 17.79, y_hat_TDMA = 0.43
# Evaluation: v_csma = 19.18, v_tdma = 3.5
# ---
# Prot: 0, y = 25.31666612625122
# y_hat_CSMA = 17.71, y_hat_TDMA = 0.23
# Evaluation: v_csma = 19.09, v_tdma = 3.31
# ---
# Prot: 0, y = 25.733333587646484
# y_hat_CSMA = 18.02, y_hat_TDMA = 0.39
# Evaluation: v_csma = 19.38, v_tdma = 3.48
# ---
# Prot: 0, y = 25.121264457702637
# y_hat_CSMA = 17.51, y_hat_TDMA = 0.25
# Evaluation: v_csma = 18.87, v_tdma = 3.34
# ---
# Prot: 0, y = 30.089654207229614
# y_hat_CSMA = 19.61, y_hat_TDMA = 0.34
# Evaluation: v_csma = 20.96, v_tdma = 3.44
# ---
# Prot: 0, y = 30.40574812889099
# y_hat_CSMA = 20.32, y_hat_TDMA = 2.6
# Evaluation: v_csma = 21.66, v_tdma = 5.71
# ---
# Prot: 0, y = 29.716665983200073
# y_hat_CSMA = 21.07, y_hat_TDMA = 3.39
# Evaluation: v_csma = 22.4, v_tdma = 6.5
# No. of new estimators = 10
# ---
# Prot: 0, y = 30.40000033378601
# y_hat_CSMA = 23.32, y_hat_TDMA = 3.52
# Evaluation: v_csma = 24.64, v_tdma = 6.64
# ---
# Prot: 0, y = 31.43333339691162
# y_hat_CSMA = 22.89, y_hat_TDMA = 3.48
# Evaluation: v_csma = 24.21, v_tdma = 6.6
# ---
# Prot: 0, y = 31.016666412353516
# y_hat_CSMA = 22.84, y_hat_TDMA = 3.44
# Evaluation: v_csma = 24.15, v_tdma = 6.57
# ---
# Prot: 0, y = 33.120115637779236
# y_hat_CSMA = 25.14, y_hat_TDMA = 5.15
# Evaluation: v_csma = 26.44, v_tdma = 8.28
# ---
# Prot: 0, y = 34.325862765312195
# y_hat_CSMA = 25.87, y_hat_TDMA = 6.6
# Evaluation: v_csma = 27.16, v_tdma = 9.73
# ---
# Prot: 0, y = 31.27988526970148
# y_hat_CSMA = 27.51, y_hat_TDMA = 6.87
# Evaluation: v_csma = 28.79, v_tdma = 10.01
# ---
# Prot: 0, y = 31.33333334326744
# y_hat_CSMA = 25.44, y_hat_TDMA = 6.08
# Evaluation: v_csma = 26.72, v_tdma = 9.22
# ---
# Prot: 0, y = 31.488506078720093
# y_hat_CSMA = 25.73, y_hat_TDMA = 6.22
# Evaluation: v_csma = 27.0, v_tdma = 9.36
# ---
# Prot: 0, y = 30.033333629369736
# y_hat_CSMA = 25.73, y_hat_TDMA = 6.2
# Evaluation: v_csma = 26.99, v_tdma = 9.35
# ---
# Prot: 0, y = 30.348850725218654
# y_hat_CSMA = 26.68, y_hat_TDMA = 7.58
# Evaluation: v_csma = 27.93, v_tdma = 10.74
# No. of new estimators = 10
# ---
